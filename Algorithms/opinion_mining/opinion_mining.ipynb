# %% [markdown]
# # Paper

# %% [markdown]
#     - Towards identifying distance between opinions

# %%
import tagme
import os
import pandas as pd
import numpy as np
from tqdm import tqdm


import itertools
import tarfile
from collections import defaultdict

import string

import nltk
nltk.download('punkt')
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer

import xlrd


from dotenv import load_dotenv
load_dotenv()
base_dir = '../../data/ssr/'
tagme.GCUBE_TOKEN = os.getenv("GCUBE_TOKEN")
# Out:
# [nltk_data] Downloading package punkt to /home/tusharm/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Random sampling 10K tweets

# %%
import random
tweet_ids = set()
while len(tweet_ids) <10000:
    tweet_ids.add(random.randrange(0,annotation_df.shape[0]))

# %%
# sampled tweets
sampled_df = annotation_df[annotation_df.index.isin(list(tweet_ids))]

# %%
sampled_df.head()
# Out:
#                 User ID                  Tweet ID  \
# 0    775702352523296770  5f1879402d4d197ddb3f7d88
# 3   1209664517220659200  5f1879412d4d197ddb3f7e10
# 7   1206274223980703744  5f1879442d4d197ddb3f7ef7
# 19  1284574640799543297  5f1879482d4d197ddb3f8061
# 21  1266220705609248768  5f1879492d4d197ddb3f80a1
#
#                                                 Tweet  \
# 0   We want justice for  is my support in this fig...
# 3   "Let's get mix more people with us for this fi...
# 7   Sirjee  \nI think you are more than enough for...
# 19  #Candle4SSR\nWhy only    along with the people...
# 21  The person who says that  Committed suicide I ...
#
#                         Hashtags  \
# 0   #Candle4SSR,#candle4sushant,
# 3       #Candle4SSR,#Candle4SSR,
# 7                   #Candle4SSR,
# 19                  #Candle4SSR,
# 21   #cbiforsushant,#Candle4SSR,
#
#                                          tagged users Language username
# 0   ['ishkarnBHANDARI', 'lostsoul_apu', 'justice_s...       en      NaN
# 3                                                  []       en      NaN
# 7              ['ishkarnBHANDARI', 'Official_Arnab_']       en      NaN
# 19  ['KanganaTeam', 'ishkarnBHANDARI', 'Swamy39', ...       en      NaN
# 21                      ['itsSSR', 'Republic_Bharat']       en      NaN

# %%
sampled_df.to_csv('sampled_10K_tweets.csv', index = False)

# %% [markdown]
# # TagMe API

# %%
lunch_annotations = tagme.annotate("My favourite meal is Mexican burritos.")
for ann in lunch_annotations.get_annotations(0.1):
    print(ann)
# Out:
# meal -> Meal (score: 0.2014230340719223)
# Mexican -> Mexican cuisine (score: 0.36614900827407837)
# burritos -> Burrito (score: 0.28607892990112305)

# %%
tomatoes_mentions = tagme.mentions("I definitely like ice cream better than tomatoes.")

for mention in tomatoes_mentions.mentions:
    print(mention)
# Out:
# ice cream [18,27] lp=0.18749085068702698
# tomatoes [40,48] lp=0.004235605709254742

# %%
rels = tagme.relatedness_title(("Barack Obama", "Italy"))
print("Obama and italy have a semantic relation of", rels.relatedness[0].rel)
# Out:
# Obama and italy have a semantic relation of 0.05192309617996216

# %%
pre_processed_tweets = pd.read_pickle(f'{base_dir}pre-processed-ssr-tweets.pkl')
pre_processed_tweets.head()
# Out:
#                        created_at              User_ID  \
# 0  Wed Jul 22 17:37:02 +0000 2020  1251870540454912002
# 1  Wed Jul 22 17:37:02 +0000 2020           1258970340
# 2  Wed Jul 22 17:37:02 +0000 2020  1276202098816716800
# 3  Wed Jul 22 17:37:02 +0000 2020  1162601829085016065
# 4  Wed Jul 22 17:37:02 +0000 2020           2758419409
#
#                                           tweet_text  retweeted_from  \
# 0  b"RT @Isha34576744: We will win..\n\nStay toge...    1.285989e+18
# 1  b'RT @KuttuRobin1: We will make it World Recor...    1.285970e+18
# 2  b'RT @DhamiKour: #Candle4SSR we want justice f...    1.285989e+18
# 3  b'RT @kushal02yadav: #Candle4SSR\nFair and tra...    1.285969e+18
# 4  b'RT @republic: #JusticeforSSR | Kangana Ranau...    1.285987e+18
#
#                                      retweeted_tweet  \
# 0  b"We will win..\n\nStay together and support e...
# 1  b'We will make it World Record..!!\n\nWe are w...
# 2  b'#Candle4SSR we want justice for SSR because ...
# 3  b'#Candle4SSR\nFair and transparent investigat...
# 4  b"#JusticeforSSR | Kangana Ranaut has sent a m...
#
#                          ID  \
# 0  5f1879402d4d197ddb3f7d59
# 1  5f1879402d4d197ddb3f7d5a
# 2  5f1879402d4d197ddb3f7d5c
# 3  5f1879402d4d197ddb3f7d5e
# 4  5f1879402d4d197ddb3f7d5f
#
#                                               tweets  \
# 0  b"RT @Isha34576744: We will win..\n\nStay toge...
# 1  b'RT @KuttuRobin1: We will make it World Recor...
# 2  b'RT @DhamiKour: #Candle4SSR we want justice f...
# 3  b'RT @kushal02yadav: #Candle4SSR\nFair and tra...
# 4  b'RT @republic: #JusticeforSSR | Kangana Ranau...
#
#                                          tidy_tweets  \
# 0  will stay together support each other sach par...
# 1                        will make world record with
# 2  want justice because this murderer want justic...
# 3  transparent investigation needed case request ...
# 4  kangana ranaut sent message mumbai police sayi...
#
#                                    tidy_tweet_tokens  \
# 0  [will, stay, together, support, each, other, s...
# 1                  [will, make, world, record, with]
# 2  [want, justice, because, this, murderer, want,...
# 3  [transparent, investigation, needed, case, req...
# 4  [kangana, ranaut, sent, message, mumbai, polic...
#
#                                       tokens_no_stop
# 0  [stay, together, support, sach, pareshan, sakt...
# 1                              [make, world, record]
# 2  [want, justice, murderer, want, justice, inquiry]
# 3  [transparent, investigation, needed, case, req...
# 4  [kangana, ranaut, sent, message, mumbai, polic...

# %%
annotation_df = pd.read_csv(f'{base_dir}ssr_annotation_language.csv')
annotation_df.head()
# Out:
#                User ID                  Tweet ID  \
# 0   775702352523296770  5f1879402d4d197ddb3f7d88
# 1  1082351503354908672  5f1879412d4d197ddb3f7dc2
# 2  1234061913073618945  5f1879412d4d197ddb3f7e09
# 3  1209664517220659200  5f1879412d4d197ddb3f7e10
# 4  1026777124844306432  5f1879422d4d197ddb3f7e1f
#
#                                                Tweet  \
# 0  We want justice for  is my support in this fig...
# 1               Nhi raha ek kamyab insan #Candle4SSR
# 2          #Candle4SSR\n1 million for our real hero.
# 3  "Let's get mix more people with us for this fi...
# 4  Thanks  for being with us to seek justice! \nN...
#
#                        Hashtags  \
# 0  #Candle4SSR,#candle4sushant,
# 1                  #Candle4SSR,
# 2                  #Candle4SSR,
# 3      #Candle4SSR,#Candle4SSR,
# 4                  #Candle4SSR,
#
#                                         tagged users Language username
# 0  ['ishkarnBHANDARI', 'lostsoul_apu', 'justice_s...       en      NaN
# 1                                                 []       so      NaN
# 2                                                 []       en      NaN
# 3                                                 []       en      NaN
# 4             ['AkshayeOfficial', 'ishkarnBHANDARI']       en      NaN

# %%
subjects_per_tweet = {}
for i,r in tqdm(annotation_df.iterrows()):
    lunch_annotations = tagme.annotate(r['Tweet'])
    mentions = lunch_annotations.get_annotations(0.2)
    subjects_per_tweet[r['Tweet ID']] = []
    for ann in mentions:
        temp = {}
        temp['begin'] = ann.begin # starting index of subject
        temp['end'] = ann.end # ending index of subject
        temp['entity_title'] = ann.entity_title # wikipedia broader name
        temp['mention'] = ann.mention # subject identified
        temp['score'] = ann.score # opinion score
        subjects_per_tweet[r['Tweet ID']].append(temp)
    if len(subjects_per_tweet[r['Tweet ID']])==0:
        subjects_per_tweet.pop(r['Tweet ID'])
# Out:
# 4598it [1:11:07,  1.10it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 11955it [3:04:22,  1.09it/s]

# %%
subjects_per_tweet
# Out:
# {'5f1879422d4d197ddb3f7e1f': [{'begin': 34,
#    'end': 41,
#    'entity_title': 'Justice (band)',
#    'mention': 'justice',
#    'score': 0.23570901155471802}],
#  '5f1879422d4d197ddb3f7e3d': [{'begin': 31,
#    'end': 39,
#    'entity_title': 'Nepotism',
#    'mention': 'nepotism',
#    'score': 0.24871794879436493}],
#  '5f1879432d4d197ddb3f7e9a': [{'begin': 29,
#    'end': 38,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.41177576780319214}],
#  '5f1879442d4d197ddb3f7ef7': [{'begin': 164,
#    'end': 173,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.3659946322441101}],
#  '5f1879442d4d197ddb3f7f08': [{'begin': 16,
#    'end': 20,
#    'entity_title': 'Network interface controller',
#    'mention': 'nPar',
#    'score': 0.3571428656578064},
#   {'begin': 66,
#    'end': 70,
#    'entity_title': 'Odin',
#    'mention': 'harr',
#    'score': 0.3143066465854645},
#   {'begin': 111,
#    'end': 114,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408}],
#  '5f1879442d4d197ddb3f7f1d': [{'begin': 9,
#    'end': 16,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408},
#   {'begin': 126,
#    'end': 130,
#    'entity_title': 'Soul',
#    'mention': 'soul',
#    'score': 0.26670271158218384},
#   {'begin': 134,
#    'end': 147,
#    'entity_title': 'Rest in peace',
#    'mention': 'rest in peace',
#    'score': 0.24439841508865356}],
#  '5f1879452d4d197ddb3f7f52': [{'begin': 0,
#    'end': 16,
#    'entity_title': 'Rhea Chakraborty',
#    'mention': 'Rhea Chakraborty',
#    'score': 0.8462952375411987},
#   {'begin': 36,
#    'end': 56,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f1879452d4d197ddb3f7f67': [{'begin': 0,
#    'end': 5,
#    'entity_title': 'Twitter',
#    'mention': 'Tweet',
#    'score': 0.4145076870918274},
#   {'begin': 10,
#    'end': 17,
#    'entity_title': 'Twitter',
#    'mention': 'retweet',
#    'score': 0.4128054976463318}],
#  '5f1879452d4d197ddb3f7f73': [{'begin': 15,
#    'end': 20,
#    'entity_title': 'Twitter',
#    'mention': 'tweet',
#    'score': 0.4683231711387634},
#   {'begin': 23,
#    'end': 30,
#    'entity_title': 'Twitter',
#    'mention': 'retweet',
#    'score': 0.4738842844963074},
#   {'begin': 45,
#    'end': 48,
#    'entity_title': 'Canadian Hot 100',
#    'mention': 'can',
#    'score': 0.21263191103935242}],
#  '5f1879452d4d197ddb3f7f8e': [{'begin': 7,
#    'end': 16,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.4686800539493561},
#   {'begin': 18,
#    'end': 23,
#    'entity_title': 'Mafia (1993 film)',
#    'mention': 'mafia',
#    'score': 0.2036139965057373},
#   {'begin': 78,
#    'end': 90,
#    'entity_title': 'Arabian Sea',
#    'mention': 'Arabian  sea',
#    'score': 0.43220338225364685}],
#  '5f1879482d4d197ddb3f805d': [{'begin': 10,
#    'end': 17,
#    'entity_title': 'Brother Records',
#    'mention': 'Brother',
#    'score': 0.30441370606422424},
#   {'begin': 137,
#    'end': 140,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408}],
#  '5f1879482d4d197ddb3f8061': [{'begin': 99,
#    'end': 106,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408},
#   {'begin': 154,
#    'end': 163,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.480262815952301}],
#  '5f1879492d4d197ddb3f808e': [{'begin': 68,
#    'end': 88,
#    'entity_title': "Let's Go All the Way (song)",
#    'mention': "let's go All The Way",
#    'score': 0.36538460850715637}],
#  '5f1879492d4d197ddb3f80a1': [{'begin': 99,
#    'end': 105,
#    'entity_title': 'The A Word',
#    'mention': 'a word',
#    'score': 0.20000000298023224}],
#  '5f1879492d4d197ddb3f80ba': [{'begin': 12,
#    'end': 15,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f18794a2d4d197ddb3f80df': [{'begin': 69,
#    'end': 89,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5},
#   {'begin': 83,
#    'end': 89,
#    'entity_title': 'Rajput',
#    'mention': 'Rajput',
#    'score': 0.44483238458633423},
#   {'begin': 129,
#    'end': 135,
#    'entity_title': 'Chhatrapati Shivaji Terminus',
#    'mention': 'mumbai',
#    'score': 0.5348896384239197},
#   {'begin': 129,
#    'end': 142,
#    'entity_title': 'Mumbai Police',
#    'mention': 'mumbai police',
#    'score': 0.5284782648086548},
#   {'begin': 205,
#    'end': 214,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.3692857027053833}],
#  '5f18794a2d4d197ddb3f811b': [{'begin': 25,
#    'end': 34,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.40567922592163086},
#   {'begin': 134,
#    'end': 137,
#    'entity_title': 'Central African CFA franc',
#    'mention': 'xaf',
#    'score': 0.5200574398040771}],
#  '5f18794b2d4d197ddb3f8132': [{'begin': 0,
#    'end': 13,
#    'entity_title': 'Preamble to the United States Constitution',
#    'mention': 'We the people',
#    'score': 0.28431445360183716},
#   {'begin': 73,
#    'end': 80,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408},
#   {'begin': 111,
#    'end': 131,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f18794b2d4d197ddb3f8166': [{'begin': 13,
#    'end': 19,
#    'entity_title': 'Syria',
#    'mention': 'suriya',
#    'score': 0.5040716528892517}],
#  '5f18794c2d4d197ddb3f81dd': [{'begin': 80,
#    'end': 83,
#    'entity_title': 'Xbox 360',
#    'mention': 'xb2',
#    'score': 0.2714976370334625}],
#  '5f18794c2d4d197ddb3f81e6': [{'begin': 20,
#    'end': 40,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f18794d2d4d197ddb3f81f9': [{'begin': 61,
#    'end': 70,
#    'entity_title': 'Bollywood',
#    'mention': 'bollywood',
#    'score': 0.35118743777275085},
#   {'begin': 209,
#    'end': 216,
#    'entity_title': 'Justice',
#    'mention': 'justice',
#    'score': 0.2699587047100067}],
#  '5f18794d2d4d197ddb3f820f': [{'begin': 6,
#    'end': 18,
#    'entity_title': 'Middle class',
#    'mention': 'middle class',
#    'score': 0.2993351221084595},
#   {'begin': 94,
#    'end': 103,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.40233996510505676},
#   {'begin': 123,
#    'end': 130,
#    'entity_title': 'For but not with',
#    'mention': 'But not',
#    'score': 0.46666666865348816}],
#  '5f18794e2d4d197ddb3f8282': [{'begin': 48,
#    'end': 56,
#    'entity_title': 'Nepotism (The Office)',
#    'mention': 'nepotism',
#    'score': 0.24871794879436493},
#   {'begin': 68,
#    'end': 71,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f18794f2d4d197ddb3f82c7': [{'begin': 0,
#    'end': 19,
#    'entity_title': 'Long, Long Way to Go',
#    'mention': 'Long long way to go',
#    'score': 0.4642857015132904}],
#  '5f18794f2d4d197ddb3f82d7': [{'begin': 99,
#    'end': 112,
#    'entity_title': 'Arnab Goswami',
#    'mention': 'arnab_goswami',
#    'score': 0.5}],
#  '5f18794f2d4d197ddb3f82e7': [{'begin': 41,
#    'end': 44,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 52,
#    'end': 59,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f1879512d4d197ddb3f83a6': [{'begin': 15,
#    'end': 20,
#    'entity_title': 'Karna',
#    'mention': 'karna',
#    'score': 0.3917355239391327},
#   {'begin': 92,
#    'end': 96,
#    'entity_title': 'Pata (sword)',
#    'mention': 'pata',
#    'score': 0.2184259593486786}],
#  '5f1879512d4d197ddb3f83b9': [{'begin': 47,
#    'end': 55,
#    'entity_title': 'Gangs of Wasseypur',
#    'mention': 'Gangs of',
#    'score': 0.4602610468864441},
#   {'begin': 56,
#    'end': 65,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.43580591678619385},
#   {'begin': 79,
#    'end': 86,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408},
#   {'begin': 148,
#    'end': 157,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.7435823678970337},
#   {'begin': 158,
#    'end': 170,
#    'entity_title': 'Bollywood',
#    'mention': 'Hindi cinema',
#    'score': 0.769961953163147}],
#  '5f1879512d4d197ddb3f83cf': [{'begin': 13,
#    'end': 16,
#    'entity_title': 'Central African CFA franc',
#    'mention': 'xaf',
#    'score': 0.46666666865348816},
#   {'begin': 21,
#    'end': 24,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408},
#   {'begin': 71,
#    'end': 74,
#    'entity_title': 'Central African CFA franc',
#    'mention': 'xaf',
#    'score': 0.46666666865348816},
#   {'begin': 79,
#    'end': 82,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408}],
#  '5f1879522d4d197ddb3f840f': [{'begin': 36,
#    'end': 43,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f1879522d4d197ddb3f8410': [{'begin': 254,
#    'end': 260,
#    'entity_title': 'Matter',
#    'mention': 'matter',
#    'score': 0.2641252279281616}],
#  '5f1879542d4d197ddb3f8435': [{'begin': 24,
#    'end': 27,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWE',
#    'score': 0.3333333432674408},
#   {'begin': 43,
#    'end': 52,
#    'entity_title': 'Bollywood',
#    'mention': 'BOLLYWOOD',
#    'score': 0.35300275683403015}],
#  '5f1879542d4d197ddb3f8479': [{'begin': 64,
#    'end': 75,
#    'entity_title': 'Salman Khan',
#    'mention': 'Salman Khan',
#    'score': 0.5}],
#  '5f1879552d4d197ddb3f84af': [{'begin': 0,
#    'end': 5,
#    'entity_title': 'India',
#    'mention': 'India',
#    'score': 0.3618861436843872}],
#  '5f1879572d4d197ddb3f8565': [{'begin': 0,
#    'end': 3,
#    'entity_title': 'The Notorious B.I.G.',
#    'mention': 'Big',
#    'score': 0.30857908725738525},
#   {'begin': 4,
#    'end': 14,
#    'entity_title': 'Conspiracy (Junior M.A.F.I.A. album)',
#    'mention': 'conspiracy',
#    'score': 0.21565712988376617},
#   {'begin': 24,
#    'end': 27,
#    'entity_title': 'Central Bureau of Investigation',
#    'mention': 'CBI',
#    'score': 0.24313554167747498}],
#  '5f1879572d4d197ddb3f857e': [{'begin': 20,
#    'end': 27,
#    'entity_title': 'Twitter',
#    'mention': 'twitter',
#    'score': 0.36211758852005005}],
#  '5f1879572d4d197ddb3f8588': [{'begin': 30,
#    'end': 36,
#    'entity_title': 'Chhatrapati Shivaji Terminus',
#    'mention': 'mumbai',
#    'score': 0.5348896384239197},
#   {'begin': 30,
#    'end': 43,
#    'entity_title': 'Mumbai Police',
#    'mention': 'mumbai police',
#    'score': 0.5284782648086548},
#   {'begin': 74,
#    'end': 79,
#    'entity_title': 'Truth',
#    'mention': 'truth',
#    'score': 0.2225399762392044}],
#  '5f1879582d4d197ddb3f85ba': [{'begin': 0,
#    'end': 17,
#    'entity_title': 'Not a Day Goes By',
#    'mention': 'Not a day goes by',
#    'score': 0.260869562625885}],
#  '5f1879582d4d197ddb3f85e2': [{'begin': 61,
#    'end': 68,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408},
#   {'begin': 153,
#    'end': 159,
#    'entity_title': 'People (magazine)',
#    'mention': 'people',
#    'score': 0.21913838386535645}],
#  '5f1879582d4d197ddb3f85ff': [{'begin': 14,
#    'end': 17,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 22,
#    'end': 28,
#    'entity_title': 'F-number',
#    'mention': 't stop',
#    'score': 0.3571428656578064},
#   {'begin': 53,
#    'end': 60,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f1879592d4d197ddb3f8658': [{'begin': 46,
#    'end': 53,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408}],
#  '5f18795a2d4d197ddb3f869c': [{'begin': 58,
#    'end': 71,
#    'entity_title': 'Gone Too Soon',
#    'mention': 'gone too soon',
#    'score': 0.40697672963142395}],
#  '5f18795c2d4d197ddb3f8749': [{'begin': 58,
#    'end': 65,
#    'entity_title': 'On Our Own (1994 TV series)',
#    'mention': 'our own',
#    'score': 0.21324318647384644},
#   {'begin': 72,
#    'end': 79,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408}],
#  '5f18795c2d4d197ddb3f8753': [{'begin': 50,
#    'end': 57,
#    'entity_title': 'Beloved (Glay album)',
#    'mention': 'beloved',
#    'score': 0.4083036482334137},
#   {'begin': 58,
#    'end': 67,
#    'entity_title': 'Pure Soul',
#    'mention': 'pure soul',
#    'score': 0.4730278253555298},
#   {'begin': 82,
#    'end': 89,
#    'entity_title': 'Prayer',
#    'mention': 'Prayers',
#    'score': 0.27189502120018005},
#   {'begin': 98,
#    'end': 104,
#    'entity_title': 'Family',
#    'mention': 'family',
#    'score': 0.28127747774124146}],
#  '5f18795c2d4d197ddb3f8773': [{'begin': 18,
#    'end': 22,
#    'entity_title': 'KRKE',
#    'mention': 'krke',
#    'score': 0.5},
#   {'begin': 40,
#    'end': 46,
#    'entity_title': 'F-number',
#    'mention': 't stop',
#    'score': 0.38185974955558777}],
#  '5f18795d2d4d197ddb3f87b8': [{'begin': 20,
#    'end': 27,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408}],
#  '5f18795d2d4d197ddb3f87d8': [{'begin': 84,
#    'end': 87,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f18795d2d4d197ddb3f87e2': [{'begin': 27,
#    'end': 32,
#    'entity_title': 'Ranjit Singh',
#    'mention': 'singh',
#    'score': 0.2188367247581482},
#   {'begin': 33,
#    'end': 39,
#    'entity_title': 'Rajput',
#    'mention': 'rajput',
#    'score': 0.515659749507904}],
#  '5f18795d2d4d197ddb3f87fa': [{'begin': 88,
#    'end': 91,
#    'entity_title': 'Niš',
#    'mention': 'nIs',
#    'score': 0.294572114944458}],
#  '5f18795f2d4d197ddb3f8842': [{'begin': 116,
#    'end': 121,
#    'entity_title': 'Smile (Charlie Chaplin song)',
#    'mention': 'SMILE',
#    'score': 0.2851458489894867}],
#  '5f1879602d4d197ddb3f885b': [{'begin': 14,
#    'end': 17,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 39,
#    'end': 46,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f1879602d4d197ddb3f8896': [{'begin': 21,
#    'end': 41,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5},
#   {'begin': 35,
#    'end': 41,
#    'entity_title': 'Rajput',
#    'mention': 'Rajput',
#    'score': 0.400162011384964},
#   {'begin': 76,
#    'end': 83,
#    'entity_title': 'Justice',
#    'mention': 'justice',
#    'score': 0.2824142873287201}],
#  '5f1879622d4d197ddb3f892d': [{'begin': 72,
#    'end': 75,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 133,
#    'end': 136,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 183,
#    'end': 192,
#    'entity_title': 'The Godfather',
#    'mention': 'godfather',
#    'score': 0.2228168547153473}],
#  '5f1879652d4d197ddb3f8a4f': [{'begin': 21,
#    'end': 26,
#    'entity_title': 'Electric power',
#    'mention': 'power',
#    'score': 0.20114974677562714},
#   {'begin': 30,
#    'end': 35,
#    'entity_title': '1 (number)',
#    'mention': 'unity',
#    'score': 0.2190018594264984}],
#  '5f1879652d4d197ddb3f8a69': [{'begin': 15,
#    'end': 35,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'SUSHANT SINGH RAJPUT',
#    'score': 0.5},
#   {'begin': 29,
#    'end': 35,
#    'entity_title': 'Rajput',
#    'mention': 'RAJPUT',
#    'score': 0.400162011384964},
#   {'begin': 218,
#    'end': 238,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'SUSHANT SINGH RAJPUT',
#    'score': 0.5}],
#  '5f1879652d4d197ddb3f8a79': [{'begin': 8,
#    'end': 17,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.3992972671985626},
#   {'begin': 83,
#    'end': 86,
#    'entity_title': 'XBC',
#    'mention': 'xbc',
#    'score': 0.3125}],
#  '5f1879652d4d197ddb3f8a89': [{'begin': 47,
#    'end': 54,
#    'entity_title': 'Twitter',
#    'mention': 'tweeter',
#    'score': 0.2662729322910309}],
#  '5f1879662d4d197ddb3f8ac7': [{'begin': 0,
#    'end': 17,
#    'entity_title': 'Not a Day Goes By',
#    'mention': 'Not a day goes by',
#    'score': 0.260869562625885}],
#  '5f1879672d4d197ddb3f8b29': [{'begin': 12,
#    'end': 17,
#    'entity_title': 'István Ládai',
#    'mention': 'ladai',
#    'score': 0.5},
#   {'begin': 18,
#    'end': 22,
#    'entity_title': 'KHTM-LP',
#    'mention': 'khtm',
#    'score': 0.20000000298023224}],
#  '5f1879672d4d197ddb3f8b5a': [{'begin': 138,
#    'end': 145,
#    'entity_title': 'Justice',
#    'mention': 'justice',
#    'score': 0.23406200110912323}],
#  '5f1879682d4d197ddb3f8b71': [{'begin': 53,
#    'end': 55,
#    'entity_title': 'Western (genre)',
#    'mention': 'we',
#    'score': 0.22203011810779572}],
#  '5f1879682d4d197ddb3f8ba1': [{'begin': 26,
#    'end': 37,
#    'entity_title': 'Maharashtra',
#    'mention': 'Maharashtra',
#    'score': 0.4335159957408905}],
#  '5f1879682d4d197ddb3f8bc4': [{'begin': 20,
#    'end': 23,
#    'entity_title': 'Central Bureau of Investigation',
#    'mention': 'CBI',
#    'score': 0.24036580324172974},
#   {'begin': 77,
#    'end': 97,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f1879692d4d197ddb3f8bf1': [{'begin': 179,
#    'end': 187,
#    'entity_title': 'Pakistan',
#    'mention': 'Pakistan',
#    'score': 0.44679373502731323}],
#  '5f1879692d4d197ddb3f8c19': [{'begin': 159,
#    'end': 174,
#    'entity_title': 'Out for Justice',
#    'mention': 'out for justice',
#    'score': 0.43396225571632385}],
#  '5f18796c2d4d197ddb3f8c8b': [{'begin': 59,
#    'end': 66,
#    'entity_title': 'When We On',
#    'mention': 'When we',
#    'score': 0.5},
#   {'begin': 59,
#    'end': 79,
#    'entity_title': 'When We Are Together',
#    'mention': 'When we are together',
#    'score': 0.2647058963775635},
#   {'begin': 83,
#    'end': 87,
#    'entity_title': 'Free will',
#    'mention': 'will',
#    'score': 0.289532870054245},
#   {'begin': 95,
#    'end': 97,
#    'entity_title': 'Tao',
#    'mention': 'do',
#    'score': 0.2884189486503601}],
#  '5f18796d2d4d197ddb3f8d21': [{'begin': 50,
#    'end': 53,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 94,
#    'end': 100,
#    'entity_title': 'People (magazine)',
#    'mention': 'people',
#    'score': 0.20178748667240143},
#   {'begin': 130,
#    'end': 136,
#    'entity_title': 'People (magazine)',
#    'mention': 'people',
#    'score': 0.20178748667240143},
#   {'begin': 155,
#    'end': 158,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f18796d2d4d197ddb3f8d2a': [{'begin': 32,
#    'end': 44,
#    'entity_title': 'A Time for Justice',
#    'mention': 'time justice',
#    'score': 0.5}],
#  '5f18796e2d4d197ddb3f8d4d': [{'begin': 12,
#    'end': 15,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f18796e2d4d197ddb3f8d66': [{'begin': 192,
#    'end': 195,
#    'entity_title': 'Deity',
#    'mention': 'God',
#    'score': 0.23822109401226044},
#   {'begin': 213,
#    'end': 233,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f18796e2d4d197ddb3f8d8f': [{'begin': 77,
#    'end': 86,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.49149441719055176},
#   {'begin': 127,
#    'end': 131,
#    'entity_title': 'Inki',
#    'mention': 'inki',
#    'score': 0.34924179315567017}],
#  '5f18796f2d4d197ddb3f8dba': [{'begin': 30,
#    'end': 37,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f18796f2d4d197ddb3f8dfa': [{'begin': 22,
#    'end': 29,
#    'entity_title': 'Friends',
#    'mention': 'friends',
#    'score': 0.2562252879142761}],
#  '5f1879702d4d197ddb3f8e0f': [{'begin': 9,
#    'end': 15,
#    'entity_title': 'F-number',
#    'mention': 't stop',
#    'score': 0.43468332290649414},
#   {'begin': 36,
#    'end': 42,
#    'entity_title': 'Voice (grammar)',
#    'mention': 'voices',
#    'score': 0.20203198492527008},
#   {'begin': 79,
#    'end': 86,
#    'entity_title': 'Answer',
#    'mention': 'answers',
#    'score': 0.2371811717748642},
#   {'begin': 87,
#    'end': 94,
#    'entity_title': 'Justice',
#    'mention': 'justice',
#    'score': 0.279556006193161},
#   {'begin': 95,
#    'end': 99,
#    'entity_title': 'Will and testament',
#    'mention': 'will',
#    'score': 0.2559477686882019}],
#  '5f1879702d4d197ddb3f8e1f': [{'begin': 12,
#    'end': 15,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 33,
#    'end': 53,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5},
#   {'begin': 47,
#    'end': 53,
#    'entity_title': 'Rajput',
#    'mention': 'Rajput',
#    'score': 0.400162011384964},
#   {'begin': 76,
#    'end': 80,
#    'entity_title': 'Help! (song)',
#    'mention': 'help',
#    'score': 0.21051590144634247}],
#  '5f1879712d4d197ddb3f8e97': [{'begin': 76,
#    'end': 87,
#    'entity_title': 'Salman Khan',
#    'mention': 'Salman Khan',
#    'score': 0.5}],
#  '5f1879712d4d197ddb3f8ea1': [{'begin': 22,
#    'end': 26,
#    'entity_title': 'Logos',
#    'mention': 'word',
#    'score': 0.2243908941745758}],
#  '5f1879712d4d197ddb3f8ec2': [{'begin': 31,
#    'end': 34,
#    'entity_title': 'Central Bureau of Investigation',
#    'mention': 'CBI',
#    'score': 0.24313554167747498}],
#  '5f1879712d4d197ddb3f8ec5': [{'begin': 84,
#    'end': 94,
#    'entity_title': 'Inside Job (2010 film)',
#    'mention': 'inside job',
#    'score': 0.2785235047340393},
#   {'begin': 151,
#    'end': 161,
#    'entity_title': 'Inside Job (2010 film)',
#    'mention': 'inside job',
#    'score': 0.2785235047340393},
#   {'begin': 177,
#    'end': 186,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.42879462242126465},
#   {'begin': 220,
#    'end': 225,
#    'entity_title': 'Mafia',
#    'mention': 'Mafia',
#    'score': 0.27980518341064453}],
#  '5f1879732d4d197ddb3f8ef2': [{'begin': 36,
#    'end': 46,
#    'entity_title': 'Afzal Guru',
#    'mention': 'Afzal guru',
#    'score': 0.5},
#   {'begin': 79,
#    'end': 86,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f1879732d4d197ddb3f8f19': [{'begin': 28,
#    'end': 48,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5},
#   {'begin': 66,
#    'end': 69,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408}],
#  '5f1879742d4d197ddb3f8f35': [{'begin': 32,
#    'end': 46,
#    'entity_title': 'Beautiful Soul (song)',
#    'mention': 'beautiful soul',
#    'score': 0.489130437374115}],
#  '5f1879742d4d197ddb3f8f46': [{'begin': 15,
#    'end': 20,
#    'entity_title': 'Twitter',
#    'mention': 'tweet',
#    'score': 0.25818607211112976},
#   {'begin': 60,
#    'end': 80,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f1879742d4d197ddb3f8f4b': [{'begin': 29,
#    'end': 36,
#    'entity_title': 'Justice',
#    'mention': 'justice',
#    'score': 0.23388493061065674}],
#  '5f1879742d4d197ddb3f8f85': [{'begin': 95,
#    'end': 103,
#    'entity_title': 'Nicklas Nygren',
#    'mention': 'nightsky',
#    'score': 0.25}],
#  '5f1879752d4d197ddb3f8f9a': [{'begin': 22,
#    'end': 28,
#    'entity_title': 'Syria',
#    'mention': 'suriya',
#    'score': 0.47727373242378235},
#   {'begin': 29,
#    'end': 33,
#    'entity_title': 'Wale (rapper)',
#    'mention': 'wale',
#    'score': 0.3969753384590149}],
#  '5f1879752d4d197ddb3f8f9d': [{'begin': 12,
#    'end': 31,
#    'entity_title': 'Government of India',
#    'mention': 'government of India',
#    'score': 0.3840569257736206},
#   {'begin': 26,
#    'end': 31,
#    'entity_title': 'India',
#    'mention': 'India',
#    'score': 0.433821439743042}],
#  '5f1879752d4d197ddb3f8fd8': [{'begin': 8,
#    'end': 14,
#    'entity_title': 'F-number',
#    'mention': 't stop',
#    'score': 0.3571428656578064}],
#  '5f1879762d4d197ddb3f9001': [{'begin': 1,
#    'end': 5,
#    'entity_title': 'An Gyeon',
#    'mention': 'kyon',
#    'score': 0.5}],
#  '5f1879762d4d197ddb3f9024': [{'begin': 77,
#    'end': 97,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'sushant singh rajput',
#    'score': 0.5},
#   {'begin': 117,
#    'end': 123,
#    'entity_title': 'Jogging',
#    'mention': 'jogger',
#    'score': 0.2545965313911438},
#   {'begin': 124,
#    'end': 128,
#    'entity_title': 'Park',
#    'mention': 'park',
#    'score': 0.2540261447429657},
#   {'begin': 154,
#    'end': 158,
#    'entity_title': "Children's Hospital of The King's Daughters",
#    'mention': 'chkd',
#    'score': 0.5}],
#  '5f1879772d4d197ddb3f905b': [{'begin': 0,
#    'end': 5,
#    'entity_title': 'Twitter',
#    'mention': 'Tweet',
#    'score': 0.4145076870918274},
#   {'begin': 10,
#    'end': 17,
#    'entity_title': 'Twitter',
#    'mention': 'retweet',
#    'score': 0.4128054976463318}],
#  '5f1879772d4d197ddb3f9063': [{'begin': 13,
#    'end': 16,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 34,
#    'end': 41,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'SUSHANT',
#    'score': 0.3333333432674408},
#   {'begin': 104,
#    'end': 107,
#    'entity_title': 'Head louse',
#    'mention': 'nIt',
#    'score': 0.23321114480495453},
#   {'begin': 186,
#    'end': 189,
#    'entity_title': 'X87',
#    'mention': 'x87',
#    'score': 0.457446813583374}],
#  '5f1879772d4d197ddb3f9068': [{'begin': 60,
#    'end': 67,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'SUSHANT',
#    'score': 0.3333333432674408}],
#  '5f1879772d4d197ddb3f9092': [{'begin': 29,
#    'end': 38,
#    'entity_title': 'Bollywood',
#    'mention': 'bollywood',
#    'score': 0.35118743777275085}],
#  '5f1879782d4d197ddb3f90ef': [{'begin': 53,
#    'end': 56,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408}],
#  '5f1879782d4d197ddb3f90f4': [{'begin': 102,
#    'end': 105,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408}],
#  '5f1879792d4d197ddb3f9126': [{'begin': 41,
#    'end': 50,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.39341652393341064},
#   {'begin': 79,
#    'end': 88,
#    'entity_title': 'Bollywood',
#    'mention': 'BOLLYWOOD',
#    'score': 0.37002265453338623}],
#  '5f1879792d4d197ddb3f9164': [{'begin': 12,
#    'end': 17,
#    'entity_title': 'Twitter',
#    'mention': 'tweet',
#    'score': 0.32676711678504944},
#   {'begin': 22,
#    'end': 29,
#    'entity_title': 'Twitter',
#    'mention': 'retweet',
#    'score': 0.35898542404174805}],
#  '5f18797a2d4d197ddb3f9196': [{'begin': 17,
#    'end': 20,
#    'entity_title': 'Huế',
#    'mention': 'hue',
#    'score': 0.2491758167743683},
#   {'begin': 41,
#    'end': 46,
#    'entity_title': 'Alawa',
#    'mention': 'alawa',
#    'score': 0.2432432472705841}],
#  '5f18797a2d4d197ddb3f91cf': [{'begin': 14,
#    'end': 17,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f18797a2d4d197ddb3f91e0': [{'begin': 18,
#    'end': 26,
#    'entity_title': 'PR-e-Sense',
#    'mention': 'presense',
#    'score': 0.5},
#   {'begin': 27,
#    'end': 34,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f18797b2d4d197ddb3f920a': [{'begin': 119,
#    'end': 122,
#    'entity_title': 'The Who',
#    'mention': 'who',
#    'score': 0.20244988799095154},
#   {'begin': 128,
#    'end': 131,
#    'entity_title': 'HIM (Finnish band)',
#    'mention': 'him',
#    'score': 0.23244675993919373},
#   {'begin': 143,
#    'end': 156,
#    'entity_title': 'The Biggest Loser (U.S. TV series)',
#    'mention': 'biggest loser',
#    'score': 0.42995691299438477}],
#  '5f18797d2d4d197ddb3f9251': [{'begin': 33,
#    'end': 53,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5},
#   {'begin': 47,
#    'end': 53,
#    'entity_title': 'Rajput',
#    'mention': 'Rajput',
#    'score': 0.4932284951210022}],
#  '5f18797d2d4d197ddb3f9260': [{'begin': 109,
#    'end': 113,
#    'entity_title': 'Network interface controller',
#    'mention': 'nPar',
#    'score': 0.3571428656578064},
#   {'begin': 114,
#    'end': 120,
#    'entity_title': 'Ab Nai',
#    'mention': 'ab nai',
#    'score': 0.5},
#   {'begin': 162,
#    'end': 165,
#    'entity_title': 'X87',
#    'mention': 'x87',
#    'score': 0.457446813583374},
#   {'begin': 194,
#    'end': 197,
#    'entity_title': 'Central African CFA franc',
#    'mention': 'xaf',
#    'score': 0.46666666865348816},
#   {'begin': 202,
#    'end': 205,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408}],
#  '5f18797e2d4d197ddb3f92c5': [{'begin': 97,
#    'end': 100,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 111,
#    'end': 114,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 177,
#    'end': 184,
#    'entity_title': 'Justice',
#    'mention': 'justice',
#    'score': 0.21706578135490417}],
#  '5f18797f2d4d197ddb3f9316': [{'begin': 18,
#    'end': 24,
#    'entity_title': 'Bhakti',
#    'mention': 'bhakti',
#    'score': 0.22654370963573456}],
#  '5f18797f2d4d197ddb3f9357': [{'begin': 80,
#    'end': 87,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f1879802d4d197ddb3f9372': [{'begin': 11,
#    'end': 16,
#    'entity_title': 'Twitter',
#    'mention': 'tweet',
#    'score': 0.270028680562973},
#   {'begin': 32,
#    'end': 35,
#    'entity_title': 'Product placement',
#    'mention': 'ppl',
#    'score': 0.24383950233459473},
#   {'begin': 67,
#    'end': 81,
#    'entity_title': 'Hrithik Roshan',
#    'mention': 'Hrithik Roshan',
#    'score': 0.5},
#   {'begin': 106,
#    'end': 126,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5},
#   {'begin': 157,
#    'end': 159,
#    'entity_title': 'Thallium',
#    'mention': 'TL',
#    'score': 0.2784999907016754},
#   {'begin': 180,
#    'end': 186,
#    'entity_title': 'Krrish',
#    'mention': 'Krrish',
#    'score': 0.5}],
#  '5f1879812d4d197ddb3f93e2': [{'begin': 103,
#    'end': 106,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 124,
#    'end': 144,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f1879812d4d197ddb3f93f9': [{'begin': 100,
#    'end': 120,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f1879812d4d197ddb3f9419': [{'begin': 30,
#    'end': 36,
#    'entity_title': 'Steel fence post',
#    'mention': 't post',
#    'score': 0.5}],
#  '5f1879822d4d197ddb3f9438': [{'begin': 12,
#    'end': 21,
#    'entity_title': 'Bollywood',
#    'mention': 'bollywood',
#    'score': 0.38390520215034485},
#   {'begin': 61,
#    'end': 68,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408}],
#  '5f1879822d4d197ddb3f944a': [{'begin': 13,
#    'end': 18,
#    'entity_title': 'Debra Milke',
#    'mention': 'milke',
#    'score': 0.2142857164144516}],
#  '5f1879842d4d197ddb3f950f': [{'begin': 2,
#    'end': 4,
#    'entity_title': '.ht',
#    'mention': 'ht',
#    'score': 0.20769019424915314},
#   {'begin': 10,
#    'end': 17,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408},
#   {'begin': 18,
#    'end': 20,
#    'entity_title': '.ke',
#    'mention': 'ke',
#    'score': 0.2077997773885727}],
#  '5f1879842d4d197ddb3f9513': [{'begin': 24,
#    'end': 28,
#    'entity_title': 'Steve Apke',
#    'mention': 'apke',
#    'score': 0.5},
#   {'begin': 99,
#    'end': 104,
#    'entity_title': 'Lekin...',
#    'mention': 'lekin',
#    'score': 0.5},
#   {'begin': 121,
#    'end': 124,
#    'entity_title': 'Central African CFA franc',
#    'mention': 'xaf',
#    'score': 0.46666666865348816},
#   {'begin': 128,
#    'end': 131,
#    'entity_title': 'JLA (comic book)',
#    'mention': 'jla',
#    'score': 0.20757363736629486}],
#  '5f1879842d4d197ddb3f9517': [{'begin': 74,
#    'end': 81,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f1879842d4d197ddb3f9529': [{'begin': 5,
#    'end': 14,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.3900876045227051},
#   {'begin': 63,
#    'end': 72,
#    'entity_title': 'Heartless (Kanye West song)',
#    'mention': 'heartless',
#    'score': 0.23367393016815186}],
#  '5f1879842d4d197ddb3f953a': [{'begin': 0,
#    'end': 7,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408},
#   {'begin': 60,
#    'end': 64,
#    'entity_title': 'Soul music',
#    'mention': 'soul',
#    'score': 0.23462650179862976}],
#  '5f1879852d4d197ddb3f95c0': [{'begin': 12,
#    'end': 32,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5},
#   {'begin': 26,
#    'end': 32,
#    'entity_title': 'Rajput',
#    'mention': 'Rajput',
#    'score': 0.400162011384964},
#   {'begin': 58,
#    'end': 62,
#    'entity_title': 'Star',
#    'mention': 'STAR',
#    'score': 0.23841328918933868},
#   {'begin': 69,
#    'end': 74,
#    'entity_title': 'Star',
#    'mention': 'STARS',
#    'score': 0.2940995991230011},
#   {'begin': 75,
#    'end': 78,
#    'entity_title': 'Nitrogen',
#    'mention': 'n\\n',
#    'score': 0.26349788904190063}],
#  '5f1879862d4d197ddb3f95c7': [{'begin': 29,
#    'end': 36,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'SUSHANT',
#    'score': 0.3333333432674408}],
#  '5f1879862d4d197ddb3f95e9': [{'begin': 2,
#    'end': 5,
#    'entity_title': 'Or Nah (The Game song)',
#    'mention': 'Nah',
#    'score': 0.23118948936462402},
#   {'begin': 2,
#    'end': 9,
#    'entity_title': 'Loyalty and Betrayal (E-40 album)',
#    'mention': 'Nah nah',
#    'score': 0.22492757439613342},
#   {'begin': 53,
#    'end': 62,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.47084841132164}],
#  '5f1879862d4d197ddb3f95ee': [{'begin': 47,
#    'end': 52,
#    'entity_title': 'Make (software)',
#    'mention': 'nmake',
#    'score': 0.47425803542137146}],
#  '5f1879862d4d197ddb3f95f7': [{'begin': 0,
#    'end': 20,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5},
#   {'begin': 14,
#    'end': 20,
#    'entity_title': 'Rajput',
#    'mention': 'Rajput',
#    'score': 0.44483238458633423},
#   {'begin': 60,
#    'end': 66,
#    'entity_title': 'Chhatrapati Shivaji Terminus',
#    'mention': 'mumbai',
#    'score': 0.5348896384239197},
#   {'begin': 60,
#    'end': 73,
#    'entity_title': 'Mumbai Police',
#    'mention': 'mumbai police',
#    'score': 0.5284782648086548},
#   {'begin': 136,
#    'end': 145,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.3692857027053833}],
#  '5f1879872d4d197ddb3f9624': [{'begin': 25,
#    'end': 32,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'SUSHANT',
#    'score': 0.3333333432674408}],
#  '5f1879882d4d197ddb3f964e': [{'begin': 61,
#    'end': 68,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408},
#   {'begin': 153,
#    'end': 159,
#    'entity_title': 'People (magazine)',
#    'mention': 'people',
#    'score': 0.21913838386535645}],
#  '5f1879892d4d197ddb3f9691': [{'begin': 0,
#    'end': 12,
#    'entity_title': 'Mahesh Bhatt',
#    'mention': 'Mahesh Bhatt',
#    'score': 0.7568933963775635}],
#  '5f18798a2d4d197ddb3f96f8': [{'begin': 1,
#    'end': 9,
#    'entity_title': 'Yes, What?',
#    'mention': 'Yes what',
#    'score': 0.22580644488334656},
#   {'begin': 62,
#    'end': 70,
#    'entity_title': 'Pakistan',
#    'mention': 'Pakistan',
#    'score': 0.4393268823623657}],
#  '5f18798a2d4d197ddb3f970c': [{'begin': 285,
#    'end': 288,
#    'entity_title': 'KXRK',
#    'mention': 'x96',
#    'score': 0.3695652186870575}],
#  '5f18798a2d4d197ddb3f9747': [{'begin': 99,
#    'end': 110,
#    'entity_title': 'Harsh Times',
#    'mention': 'harsh times',
#    'score': 0.7095715999603271}],
#  '5f18798b2d4d197ddb3f974f': [{'begin': 14,
#    'end': 17,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 33,
#    'end': 36,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 52,
#    'end': 55,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 71,
#    'end': 74,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 90,
#    'end': 93,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 109,
#    'end': 112,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 128,
#    'end': 131,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 147,
#    'end': 150,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 166,
#    'end': 169,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 185,
#    'end': 188,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 204,
#    'end': 207,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 223,
#    'end': 226,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 242,
#    'end': 245,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f18798b2d4d197ddb3f9777': [{'begin': 21,
#    'end': 24,
#    'entity_title': 'Katholieke Radio Omroep',
#    'mention': 'kro',
#    'score': 0.23456789553165436}],
#  '5f18798b2d4d197ddb3f9787': [{'begin': 12,
#    'end': 21,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.40760308504104614},
#   {'begin': 87,
#    'end': 107,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5},
#   {'begin': 147,
#    'end': 167,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f18798c2d4d197ddb3f97c4': [{'begin': 183,
#    'end': 187,
#    'entity_title': 'Hoti (tribe)',
#    'mention': 'hoti',
#    'score': 0.22636815905570984},
#   {'begin': 196,
#    'end': 205,
#    'entity_title': 'Bollywood',
#    'mention': 'bollywood',
#    'score': 0.4354950785636902},
#   {'begin': 246,
#    'end': 249,
#    'entity_title': 'Terry Toh',
#    'mention': 'toh',
#    'score': 0.31481480598449707}],
#  '5f18798c2d4d197ddb3f97c8': [{'begin': 54,
#    'end': 67,
#    'entity_title': 'Sushant Singh',
#    'mention': 'sushant singh',
#    'score': 0.4901576638221741}],
#  '5f18798c2d4d197ddb3f97cf': [{'begin': 69,
#    'end': 89,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'sushant Singh Rajput',
#    'score': 0.5}],
#  '5f18798c2d4d197ddb3f9806': [{'begin': 52,
#    'end': 55,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f18798d2d4d197ddb3f9848': [{'begin': 15,
#    'end': 24,
#    'entity_title': 'Bollywood',
#    'mention': 'bollywood',
#    'score': 0.45510873198509216},
#   {'begin': 25,
#    'end': 29,
#    'entity_title': 'Wale (rapper)',
#    'mention': 'wale',
#    'score': 0.424537718296051},
#   {'begin': 30,
#    'end': 33,
#    'entity_title': 'Terry Toh',
#    'mention': 'toh',
#    'score': 0.31481480598449707}],
#  '5f18798d2d4d197ddb3f9870': [{'begin': 19,
#    'end': 30,
#    'entity_title': 'Ajay Devgan',
#    'mention': 'Ajay Devgan',
#    'score': 0.5}],
#  '5f18798e2d4d197ddb3f98b2': [{'begin': 29,
#    'end': 38,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.4101402163505554}],
#  '5f18798f2d4d197ddb3f98e3': [{'begin': 20,
#    'end': 27,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f18798f2d4d197ddb3f9908': [{'begin': 24,
#    'end': 44,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f18798f2d4d197ddb3f992e': [{'begin': 16,
#    'end': 22,
#    'entity_title': 'Nuclear force',
#    'mention': 'strong',
#    'score': 0.20294927060604095},
#   {'begin': 37,
#    'end': 46,
#    'entity_title': 'Pakistan Army',
#    'mention': 'pakistani',
#    'score': 0.38202744722366333},
#   {'begin': 37,
#    'end': 50,
#    'entity_title': 'Inter-Services Intelligence',
#    'mention': 'pakistani ISI',
#    'score': 0.5345025062561035},
#   {'begin': 47,
#    'end': 50,
#    'entity_title': 'Inter-Services Intelligence',
#    'mention': 'ISI',
#    'score': 0.6150760054588318},
#   {'begin': 47,
#    'end': 56,
#    'entity_title': 'Inter-Services Intelligence',
#    'mention': 'ISI agent',
#    'score': 0.34090909361839294}],
#  '5f1879902d4d197ddb3f993e': [{'begin': 114,
#    'end': 122,
#    'entity_title': 'Nepotism',
#    'mention': 'nepotism',
#    'score': 0.34758543968200684}],
#  '5f1879902d4d197ddb3f9957': [{'begin': 19,
#    'end': 24,
#    'entity_title': 'Military Intelligence Directorate (Israel)',
#    'mention': 'a man',
#    'score': 0.3333333432674408},
#   {'begin': 21,
#    'end': 28,
#    'entity_title': 'The Man Who',
#    'mention': 'man who',
#    'score': 0.23477394878864288},
#   {'begin': 69,
#    'end': 82,
#    'entity_title': '3 Commando Brigade',
#    'mention': 'Army Commando',
#    'score': 0.239533931016922},
#   {'begin': 74,
#    'end': 82,
#    'entity_title': 'British Commandos',
#    'mention': 'Commando',
#    'score': 0.2973180115222931},
#   {'begin': 90,
#    'end': 97,
#    'entity_title': 'Hanging',
#    'mention': 'hanging',
#    'score': 0.2028634250164032},
#   {'begin': 108,
#    'end': 121,
#    'entity_title': 'Strangling',
#    'mention': 'strangulation',
#    'score': 0.34703361988067627},
#   {'begin': 196,
#    'end': 209,
#    'entity_title': 'Arnab Goswami',
#    'mention': 'arnab_goswami',
#    'score': 0.5}],
#  '5f1879922d4d197ddb3f99c2': [{'begin': 23,
#    'end': 30,
#    'entity_title': 'Twitter',
#    'mention': 'Retweet',
#    'score': 0.2104419469833374}],
#  '5f1879932d4d197ddb3f9a14': [{'begin': 49,
#    'end': 57,
#    'entity_title': 'Bollywood',
#    'mention': 'Bolywood',
#    'score': 0.34996819496154785}],
#  '5f1879932d4d197ddb3f9a36': [{'begin': 27,
#    'end': 30,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f1879942d4d197ddb3f9a7f': [{'begin': 110,
#    'end': 117,
#    'entity_title': 'Justice',
#    'mention': 'justice',
#    'score': 0.20178112387657166}],
#  '5f1879942d4d197ddb3f9aa5': [{'begin': 1,
#    'end': 10,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.4526035785675049},
#   {'begin': 52,
#    'end': 57,
#    'entity_title': 'Globe',
#    'mention': 'Globe',
#    'score': 0.21636579930782318},
#   {'begin': 92,
#    'end': 99,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408},
#   {'begin': 101,
#    'end': 104,
#    'entity_title': 'THX',
#    'mention': 'Thx',
#    'score': 0.25}],
#  '5f1879952d4d197ddb3f9af0': [{'begin': 0,
#    'end': 7,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f1879962d4d197ddb3f9b2a': [{'begin': 124,
#    'end': 133,
#    'entity_title': 'My Way (Usher album)',
#    'mention': 'Come back',
#    'score': 0.2174708992242813}],
#  '5f1879962d4d197ddb3f9b2d': [{'begin': 34,
#    'end': 48,
#    'entity_title': 'Because of You (Kelly Clarkson song)',
#    'mention': 'because of you',
#    'score': 0.293718159198761},
#   {'begin': 74,
#    'end': 79,
#    'entity_title': 'Bollywood',
#    'mention': 'hindi',
#    'score': 0.3022618889808655},
#   {'begin': 119,
#    'end': 133,
#    'entity_title': 'Because of You (Kelly Clarkson song)',
#    'mention': 'Because of you',
#    'score': 0.293718159198761},
#   {'begin': 153,
#    'end': 162,
#    'entity_title': 'I Found U',
#    'mention': 'i found u',
#    'score': 0.26923078298568726}],
#  '5f1879962d4d197ddb3f9b44': [{'begin': 27,
#    'end': 38,
#    'entity_title': 'Yakub Memon',
#    'mention': 'Yakub Memon',
#    'score': 0.5},
#   {'begin': 95,
#    'end': 114,
#    'entity_title': 'Not Like the Movies',
#    'mention': 'not like the movies',
#    'score': 0.5},
#   {'begin': 124,
#    'end': 132,
#    'entity_title': 'Pakistan',
#    'mention': 'Pakistan',
#    'score': 0.4034474790096283}],
#  '5f1879962d4d197ddb3f9b53': [{'begin': 130,
#    'end': 138,
#    'entity_title': 'Nepotism',
#    'mention': 'nepotism',
#    'score': 0.3762471675872803},
#   {'begin': 214,
#    'end': 221,
#    'entity_title': 'Justice',
#    'mention': 'justice',
#    'score': 0.2445906102657318},
#   {'begin': 246,
#    'end': 253,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408}],
#  '5f1879962d4d197ddb3f9b5b': [{'begin': 84,
#    'end': 87,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f1879972d4d197ddb3f9bec': [{'begin': 0,
#    'end': 21,
#    'entity_title': 'Friends with Benefits (film)',
#    'mention': 'Friends with benefits',
#    'score': 0.4350649416446686}],
#  '5f18799a2d4d197ddb3f9c76': [{'begin': 57,
#    'end': 64,
#    'entity_title': 'Hashtag',
#    'mention': 'hashtag',
#    'score': 0.32800379395484924},
#   {'begin': 87,
#    'end': 94,
#    'entity_title': 'Twitter',
#    'mention': 'twitter',
#    'score': 0.3776533901691437},
#   {'begin': 95,
#    'end': 103,
#    'entity_title': 'Autofill',
#    'mention': 'autofill',
#    'score': 0.32499998807907104},
#   {'begin': 127,
#    'end': 134,
#    'entity_title': 'Hashtag',
#    'mention': 'hashtag',
#    'score': 0.2392418086528778},
#   {'begin': 201,
#    'end': 207,
#    'entity_title': 'Oregon Railroad and Navigation Company',
#    'mention': 'amp;\\n',
#    'score': 0.5}],
#  '5f18799b2d4d197ddb3f9cbd': [{'begin': 55,
#    'end': 59,
#    'entity_title': 'Steve Apke',
#    'mention': 'apke',
#    'score': 0.5}],
#  '5f18799b2d4d197ddb3f9cc4': [{'begin': 49,
#    'end': 57,
#    'entity_title': 'Bollywood',
#    'mention': 'Bolywood',
#    'score': 0.34996819496154785}],
#  '5f18799b2d4d197ddb3f9cf5': [{'begin': 49,
#    'end': 52,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f18799c2d4d197ddb3f9d6b': [{'begin': 49,
#    'end': 58,
#    'entity_title': 'Chingaari',
#    'mention': 'chingaari',
#    'score': 0.6112561821937561},
#   {'begin': 59,
#    'end': 62,
#    'entity_title': 'Aag (2007 film)',
#    'mention': 'Aag',
#    'score': 0.2172829806804657}],
#  '5f18799d2d4d197ddb3f9d8c': [{'begin': 26,
#    'end': 31,
#    'entity_title': 'India national cricket team',
#    'mention': 'india',
#    'score': 0.3552776873111725}],
#  '5f18799d2d4d197ddb3f9d97': [{'begin': 27,
#    'end': 47,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5},
#   {'begin': 41,
#    'end': 47,
#    'entity_title': 'Rajput',
#    'mention': 'Rajput',
#    'score': 0.49574199318885803}],
#  '5f18799d2d4d197ddb3f9da2': [{'begin': 87,
#    'end': 94,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408}],
#  '5f18799d2d4d197ddb3f9dd3': [{'begin': 21,
#    'end': 41,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'sushant Singh Rajput',
#    'score': 0.5}],
#  '5f18799e2d4d197ddb3f9e03': [{'begin': 22,
#    'end': 27,
#    'entity_title': 'Moy Hit 1',
#    'mention': 'Hit 1',
#    'score': 0.5},
#   {'begin': 128,
#    'end': 141,
#    'entity_title': 'Come Together Music Festival',
#    'mention': 'come together',
#    'score': 0.2212754487991333}],
#  '5f18799f2d4d197ddb3f9e67': [{'begin': 98,
#    'end': 106,
#    'entity_title': 'Nepotism',
#    'mention': 'nepotism',
#    'score': 0.25909388065338135}],
#  '5f18799f2d4d197ddb3f9e7e': [{'begin': 1,
#    'end': 8,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408},
#   {'begin': 92,
#    'end': 97,
#    'entity_title': 'Fight (band)',
#    'mention': 'fight',
#    'score': 0.2645849287509918}],
#  '5f1879a02d4d197ddb3f9ed5': [{'begin': 0,
#    'end': 7,
#    'entity_title': 'Twitter',
#    'mention': 'Retweet',
#    'score': 0.34901803731918335},
#   {'begin': 12,
#    'end': 17,
#    'entity_title': 'Twitter',
#    'mention': 'Tweet',
#    'score': 0.35072022676467896}],
#  '5f1879a02d4d197ddb3f9edf': [{'begin': 66,
#    'end': 86,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f1879a12d4d197ddb3f9f50': [{'begin': 12,
#    'end': 21,
#    'entity_title': 'The Power (Snap! song)',
#    'mention': 'the power',
#    'score': 0.5491969585418701},
#   {'begin': 25,
#    'end': 30,
#    'entity_title': 'Patna',
#    'mention': 'Patna',
#    'score': 0.4608805477619171},
#   {'begin': 146,
#    'end': 154,
#    'entity_title': 'Nepotism (The Office)',
#    'mention': 'nepotism',
#    'score': 0.24871794879436493},
#   {'begin': 178,
#    'end': 181,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408}],
#  '5f1879a12d4d197ddb3f9f5d': [{'begin': 71,
#    'end': 80,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.4434677064418793},
#   {'begin': 101,
#    'end': 114,
# ...
#    'mention': 'Bollywood',
#    'score': 0.3862834572792053},
#   {'begin': 20,
#    'end': 26,
#    'entity_title': 'Coercion',
#    'mention': 'threat',
#    'score': 0.3123575747013092},
#   {'begin': 30,
#    'end': 37,
#    'entity_title': 'Society',
#    'mention': 'society',
#    'score': 0.2190834879875183},
#   {'begin': 114,
#    'end': 117,
#    'entity_title': 'Central Bureau of Investigation',
#    'mention': 'CBI',
#    'score': 0.32720622420310974},
#   {'begin': 131,
#    'end': 136,
#    'entity_title': 'Bihar',
#    'mention': 'Bihar',
#    'score': 0.5820198655128479},
#   {'begin': 147,
#    'end': 150,
#    'entity_title': 'National Institutes of Technology',
#    'mention': 'nIt',
#    'score': 0.2514219582080841},
#   {'begin': 191,
#    'end': 194,
#    'entity_title': 'Bharatiya Janata Party',
#    'mention': 'BJP',
#    'score': 0.21034884452819824}],
#  '5f187b1e2d4d197ddb40239c': [{'begin': 34,
#    'end': 41,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408},
#   {'begin': 47,
#    'end': 53,
#    'entity_title': 'Rajput',
#    'mention': 'Rajput',
#    'score': 0.41287368535995483}],
#  '5f187b1e2d4d197ddb4023aa': [{'begin': 15,
#    'end': 18,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f187b1f2d4d197ddb40240e': [{'begin': 29,
#    'end': 38,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.3938875198364258}],
#  '5f187b202d4d197ddb402457': [{'begin': 38,
#    'end': 41,
#    'entity_title': 'Inter-Services Intelligence',
#    'mention': 'ISI',
#    'score': 0.3887130618095398},
#   {'begin': 38,
#    'end': 47,
#    'entity_title': 'Inter-Services Intelligence',
#    'mention': 'ISI agent',
#    'score': 0.34090909361839294},
#   {'begin': 48,
#    'end': 62,
#    'entity_title': 'Aneel Mussarat',
#    'mention': 'aneel mussarat',
#    'score': 0.5},
#   {'begin': 75,
#    'end': 85,
#    'entity_title': 'Anti-Indian sentiment',
#    'mention': 'anti india',
#    'score': 0.20282495021820068},
#   {'begin': 80,
#    'end': 85,
#    'entity_title': 'India',
#    'mention': 'india',
#    'score': 0.4600573778152466},
#   {'begin': 115,
#    'end': 123,
#    'entity_title': 'Canada',
#    'mention': 'Canadian',
#    'score': 0.23584270477294922},
#   {'begin': 140,
#    'end': 149,
#    'entity_title': 'Pakistan',
#    'mention': 'Pakistani',
#    'score': 0.2848138213157654},
#   {'begin': 140,
#    'end': 153,
#    'entity_title': 'Inter-Services Intelligence',
#    'mention': 'Pakistani ISI',
#    'score': 0.3773874342441559},
#   {'begin': 150,
#    'end': 153,
#    'entity_title': 'Inter-Services Intelligence',
#    'mention': 'ISI',
#    'score': 0.5617859959602356},
#   {'begin': 150,
#    'end': 159,
#    'entity_title': 'Inter-Services Intelligence',
#    'mention': 'ISI agent',
#    'score': 0.5139819979667664},
#   {'begin': 182,
#    'end': 186,
#    'entity_title': 'Gaya confederacy',
#    'mention': 'gaya',
#    'score': 0.24679407477378845},
#   {'begin': 205,
#    'end': 214,
#    'entity_title': 'Deshdrohi',
#    'mention': 'deshdrohi',
#    'score': 0.3928571343421936},
#   {'begin': 215,
#    'end': 223,
#    'entity_title': 'Canada',
#    'mention': 'canadian',
#    'score': 0.22741267085075378}],
#  '5f187b202d4d197ddb402472': [{'begin': 13,
#    'end': 33,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'SUSHANT SINGH RAJPUT',
#    'score': 0.5}],
#  '5f187b212d4d197ddb4024a4': [{'begin': 6,
#    'end': 15,
#    'entity_title': "We'll Get By",
#    'mention': "we'll get",
#    'score': 0.26923078298568726}],
#  '5f187b212d4d197ddb4024e1': [{'begin': 20,
#    'end': 40,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f187b222d4d197ddb402527': [{'begin': 36,
#    'end': 43,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f187b222d4d197ddb402553': [{'begin': 24,
#    'end': 31,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408}],
#  '5f187b262d4d197ddb40265e': [{'begin': 15,
#    'end': 18,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f187b262d4d197ddb40266f': [{'begin': 53,
#    'end': 56,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408}],
#  '5f187b262d4d197ddb402678': [{'begin': 19,
#    'end': 29,
#    'entity_title': 'Play Dirty',
#    'mention': 'play dirty',
#    'score': 0.5236142873764038},
#   {'begin': 24,
#    'end': 34,
#    'entity_title': 'The Dirty Game',
#    'mention': 'dirty game',
#    'score': 0.2545454502105713},
#   {'begin': 62,
#    'end': 71,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.4599132835865021}],
#  '5f187b272d4d197ddb4026b9': [{'begin': 26,
#    'end': 41,
#    'entity_title': '20th Anniversary of the Million Man March: Justice or Else',
#    'mention': 'justice Or else',
#    'score': 0.5},
#   {'begin': 252,
#    'end': 266,
#    'entity_title': 'Beautiful Soul (song)',
#    'mention': 'beautiful soul',
#    'score': 0.489130437374115}],
#  '5f187b282d4d197ddb402706': [{'begin': 86,
#    'end': 92,
#    'entity_title': 'Matter (philosophy)',
#    'mention': 'matter',
#    'score': 0.20092473924160004}],
#  '5f187b292d4d197ddb402759': [{'begin': 8,
#    'end': 20,
#    'entity_title': 'Kapil Sharma (comedian)',
#    'mention': 'Kapil Sharma',
#    'score': 0.5}],
#  '5f187b292d4d197ddb402781': [{'begin': 21,
#    'end': 30,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.43079596757888794},
#   {'begin': 71,
#    'end': 80,
#    'entity_title': 'Speak Now',
#    'mention': 'speak now',
#    'score': 0.31690141558647156},
#   {'begin': 85,
#    'end': 105,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f187b292d4d197ddb40278e': [{'begin': 57,
#    'end': 75,
#    'entity_title': 'Candle in the Wind',
#    'mention': 'Candle in the Wind',
#    'score': 0.3636363744735718},
#   {'begin': 71,
#    'end': 75,
#    'entity_title': 'Wind',
#    'mention': 'Wind',
#    'score': 0.2448292374610901}],
#  '5f187b292d4d197ddb40278f': [{'begin': 8,
#    'end': 12,
#    'entity_title': 'Steve Apke',
#    'mention': 'apke',
#    'score': 0.5}],
#  '5f187b2a2d4d197ddb402819': [{'begin': 59,
#    'end': 72,
#    'entity_title': 'Fight for You',
#    'mention': 'fight for you',
#    'score': 0.2614402174949646}],
#  '5f187b2b2d4d197ddb402837': [{'begin': 36,
#    'end': 43,
#    'entity_title': 'Kingdom of England',
#    'mention': 'England',
#    'score': 0.23621335625648499},
#   {'begin': 73,
#    'end': 76,
#    'entity_title': 'Degree symbol',
#    'mention': 'xb0',
#    'score': 0.5425660610198975}],
#  '5f187b2b2d4d197ddb402849': [{'begin': 0,
#    'end': 20,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5},
#   {'begin': 38,
#    'end': 41,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408}],
#  '5f187b2d2d4d197ddb4028ff': [{'begin': 113,
#    'end': 118,
#    'entity_title': 'India',
#    'mention': 'India',
#    'score': 0.3022307753562927}],
#  '5f187b2d2d4d197ddb402938': [{'begin': 44,
#    'end': 53,
#    'entity_title': 'Thank You (Falettinme Be Mice Elf Agin)',
#    'mention': 'thank you',
#    'score': 0.2019559144973755}],
#  '5f187b302d4d197ddb4029b5': [{'begin': 42,
#    'end': 49,
#    'entity_title': 'For but not with',
#    'mention': 'but not',
#    'score': 0.46666666865348816},
#   {'begin': 50,
#    'end': 56,
#    'entity_title': 'The A Word',
#    'mention': 'a word',
#    'score': 0.20000000298023224},
#   {'begin': 61,
#    'end': 68,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408}],
#  '5f187b302d4d197ddb4029b9': [{'begin': 75,
#    'end': 84,
#    'entity_title': 'Above the Law (group)',
#    'mention': 'above law',
#    'score': 0.24189814925193787},
#   {'begin': 131,
#    'end': 144,
#    'entity_title': 'Interrogation',
#    'mention': 'interrogation',
#    'score': 0.2166978120803833}],
#  '5f187b302d4d197ddb4029c2': [{'begin': 6,
#    'end': 9,
#    'entity_title': 'Can (band)',
#    'mention': 'can',
#    'score': 0.273547500371933},
#   {'begin': 121,
#    'end': 128,
#    'entity_title': 'Justice',
#    'mention': 'justice',
#    'score': 0.25453993678092957},
#   {'begin': 134,
#    'end': 139,
#    'entity_title': 'Rights',
#    'mention': 'right',
#    'score': 0.2367788851261139},
#   {'begin': 140,
#    'end': 145,
#    'entity_title': 'Fact',
#    'mention': 'facts',
#    'score': 0.22895607352256775}],
#  '5f187b302d4d197ddb4029d4': [{'begin': 12,
#    'end': 15,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f187b312d4d197ddb402a10': [{'begin': 22,
#    'end': 31,
#    'entity_title': 'The Power (Snap! song)',
#    'mention': 'the power',
#    'score': 0.5},
#   {'begin': 85,
#    'end': 88,
#    'entity_title': 'Central African CFA franc',
#    'mention': 'xaf',
#    'score': 0.46666666865348816},
#   {'begin': 93,
#    'end': 96,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408}],
#  '5f187b312d4d197ddb402a1f': [{'begin': 47,
#    'end': 56,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.3787907063961029}],
#  '5f187b312d4d197ddb402a2c': [{'begin': 21,
#    'end': 34,
#    'entity_title': 'Arnab Goswami',
#    'mention': 'arnab_goswami',
#    'score': 0.5}],
#  '5f187b312d4d197ddb402a2f': [{'begin': 54,
#    'end': 57,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f187cc92d4d197ddb402aba': [{'begin': 154,
#    'end': 157,
#    'entity_title': 'XBC',
#    'mention': 'xbc',
#    'score': 0.3125}],
#  '5f187cca2d4d197ddb402ad9': [{'begin': 12,
#    'end': 32,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f187ccc2d4d197ddb402b9e': [{'begin': 16,
#    'end': 24,
#    'entity_title': 'Elimination races',
#    'mention': 'miss out',
#    'score': 0.2857142984867096},
#   {'begin': 45,
#    'end': 49,
#    'entity_title': 'Lucy Nkya',
#    'mention': 'nKya',
#    'score': 0.5},
#   {'begin': 63,
#    'end': 68,
#    'entity_title': 'Daala',
#    'mention': 'daala',
#    'score': 0.34090909361839294}],
#  '5f187ccc2d4d197ddb402bc6': [{'begin': 35,
#    'end': 46,
#    'entity_title': 'Maharashtra',
#    'mention': 'Maharashtra',
#    'score': 0.5910142660140991},
#   {'begin': 128,
#    'end': 131,
#    'entity_title': 'Central Bureau of Investigation',
#    'mention': 'CBI',
#    'score': 0.20197516679763794}],
#  '5f187ccc2d4d197ddb402bdc': [{'begin': 12,
#    'end': 15,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408},
#   {'begin': 50,
#    'end': 70,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant singh rajput',
#    'score': 0.5}],
#  '5f187cce2d4d197ddb402c29': [{'begin': 115,
#    'end': 118,
#    'entity_title': 'Cosmic Background Imager',
#    'mention': 'CBI',
#    'score': 0.22808635234832764}],
#  '5f187cce2d4d197ddb402c54': [{'begin': 24,
#    'end': 31,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408},
#   {'begin': 44,
#    'end': 51,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408},
#   {'begin': 64,
#    'end': 71,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408}],
#  '5f187ccf2d4d197ddb402c65': [{'begin': 0,
#    'end': 12,
#    'entity_title': "Why Don't You?",
#    'mention': 'Why dont you',
#    'score': 0.5},
#   {'begin': 73,
#    'end': 76,
#    'entity_title': 'Canon law (Catholic Church)',
#    'mention': 'Jus',
#    'score': 0.20506060123443604}],
#  '5f187ccf2d4d197ddb402cae': [{'begin': 31,
#    'end': 36,
#    'entity_title': 'Tabor Light',
#    'mention': 'light',
#    'score': 0.2211885154247284},
#   {'begin': 40,
#    'end': 47,
#    'entity_title': 'Justice',
#    'mention': 'Justice',
#    'score': 0.2492448389530182}],
#  '5f187cd02d4d197ddb402ceb': [{'begin': 122,
#    'end': 130,
#    'entity_title': 'Lockdown (2011)',
#    'mention': 'lockdown',
#    'score': 0.25810015201568604}],
#  '5f187cd02d4d197ddb402cfc': [{'begin': 35,
#    'end': 41,
#    'entity_title': 'Candle',
#    'mention': 'candle',
#    'score': 0.2211310863494873}],
#  '5f187cd02d4d197ddb402d00': [{'begin': 141,
#    'end': 144,
#    'entity_title': 'College Basketball Invitational',
#    'mention': 'CBI',
#    'score': 0.23474183678627014},
#   {'begin': 157,
#    'end': 177,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'Sushant Singh Rajput',
#    'score': 0.5}],
#  '5f187cd02d4d197ddb402d17': [{'begin': 46,
#    'end': 55,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.4607430696487427}],
#  '5f187cd12d4d197ddb402d62': [{'begin': 127,
#    'end': 135,
#    'entity_title': 'LMFAO',
#    'mention': 'with you',
#    'score': 0.27230289578437805}],
#  '5f187cd12d4d197ddb402d77': [{'begin': 45,
#    'end': 48,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408},
#   {'begin': 69,
#    'end': 72,
#    'entity_title': 'Fokker XB-8',
#    'mention': 'xb8',
#    'score': 0.3333333432674408},
#   {'begin': 77,
#    'end': 80,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  '5f187cd12d4d197ddb402d80': [{'begin': 39,
#    'end': 48,
#    'entity_title': 'Bollywood',
#    'mention': 'bollywood',
#    'score': 0.47419098019599915},
#   {'begin': 86,
#    'end': 94,
#    'entity_title': 'Heel (professional wrestling)',
#    'mention': 'villains',
#    'score': 0.23304158449172974},
#   {'begin': 115,
#    'end': 122,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408}],
#  '5f187cd12d4d197ddb402d82': [{'begin': 63,
#    'end': 70,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'sushant',
#    'score': 0.3333333432674408},
#   {'begin': 71,
#    'end': 77,
#    'entity_title': 'Chandrabhan Bhaiya',
#    'mention': 'bhaiya',
#    'score': 0.4000000059604645}],
#  '5f187cd22d4d197ddb402daa': [{'begin': 15,
#    'end': 35,
#    'entity_title': 'Sushant Singh Rajput',
#    'mention': 'SUSHANT SINGH RAJPUT',
#    'score': 0.5}],
#  '5f187cd22d4d197ddb402db2': [{'begin': 129,
#    'end': 134,
#    'entity_title': 'Akela (Jungle Book)',
#    'mention': 'akela',
#    'score': 0.2465277761220932}],
#  '5f187cd32d4d197ddb402df6': [{'begin': 8,
#    'end': 22,
#    'entity_title': 'Yash Raj Films',
#    'mention': 'Yash Raj films',
#    'score': 0.5}],
#  '5f187cd32d4d197ddb402e1d': [{'begin': 107,
#    'end': 118,
#    'entity_title': 'With or Without You',
#    'mention': 'without you',
#    'score': 0.21258530020713806}],
#  '5f187cd42d4d197ddb402e7d': [{'begin': 10,
#    'end': 29,
#    'entity_title': 'Actor',
#    'mention': 'actor &amp; actress',
#    'score': 0.3333333432674408},
#   {'begin': 61,
#    'end': 63,
#    'entity_title': 'Master of Arts',
#    'mention': 'ma',
#    'score': 0.27077701687812805},
#   {'begin': 64,
#    'end': 66,
#    'entity_title': 'Master of Arts',
#    'mention': 'am',
#    'score': 0.25592467188835144},
#   {'begin': 98,
#    'end': 102,
#    'entity_title': 'Mikkel Rønnow',
#    'mention': 'nNow',
#    'score': 0.5}],
#  '5f187cd42d4d197ddb402e9d': [{'begin': 25,
#    'end': 30,
#    'entity_title': 'Karna',
#    'mention': 'karna',
#    'score': 0.3917355239391327}],
#  '5f187cd52d4d197ddb402f05': [{'begin': 35,
#    'end': 38,
#    'entity_title': 'Central Bureau of Investigation',
#    'mention': 'CBI',
#    'score': 0.22486194968223572}],
#  '5f187cd62d4d197ddb402f23': [{'begin': 55,
#    'end': 64,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.45724502205848694},
#   {'begin': 75,
#    'end': 80,
#    'entity_title': 'India',
#    'mention': 'India',
#    'score': 0.3706779181957245},
#   {'begin': 123,
#    'end': 132,
#    'entity_title': 'Bollywood',
#    'mention': 'Bollywood',
#    'score': 0.4196345806121826}],
#  '5f187cd72d4d197ddb402f4b': [{'begin': 12,
#    'end': 18,
#    'entity_title': 'Ahmed Naseer',
#    'mention': 'Naseer',
#    'score': 0.2777777910232544},
#   {'begin': 27,
#    'end': 34,
#    'entity_title': 'Rajan Sushant',
#    'mention': 'Sushant',
#    'score': 0.3333333432674408},
#   {'begin': 50,
#    'end': 58,
#    'entity_title': 'Human nature',
#    'mention': 'humanity',
#    'score': 0.25568118691444397}],
#  '5f187cd92d4d197ddb40301d': [{'begin': 38,
#    'end': 41,
#    'entity_title': 'Yin Yin Nwe',
#    'mention': 'nWe',
#    'score': 0.3333333432674408}],
#  ...}

# %% [markdown]
# # Clustering mentions with entity_titles

# %%
mentions_to_titles = {}
for i in subjects_per_tweet.keys():
    l = subjects_per_tweet[i]
    for j in l:
        mentions_to_titles[j['mention']] = j['entity_title']
mentions_to_titles
# Out:
# {'justice': 'Justice',
#  'nepotism': 'Nepotism',
#  'Bollywood': 'Bollywood',
#  'nPar': 'Network interface controller',
#  'harr': 'Odin',
#  'xb8': 'Fokker XB-8',
#  'Sushant': 'Rajan Sushant',
#  'soul': 'Soul',
#  'rest in peace': 'Rest in peace',
#  'Rhea Chakraborty': 'Rhea Chakraborty',
#  'Sushant Singh Rajput': 'Sushant Singh Rajput',
#  'Tweet': 'Twitter',
#  'retweet': 'Twitter',
#  'tweet': 'Twitter',
#  'can': 'Can (band)',
#  'mafia': 'Mafia (1993 film)',
#  'Arabian  sea': 'Arabian Sea',
#  'Brother': 'Brother (Pearl Jam song)',
#  "let's go All The Way": "Let's Go All the Way (song)",
#  'a word': 'The A Word',
#  'nWe': 'Yin Yin Nwe',
#  'Rajput': 'Rajput',
#  'mumbai': 'Chhatrapati Shivaji Terminus',
#  'mumbai police': 'Mumbai Police',
#  'xaf': 'Central African CFA franc',
#  'We the people': 'We the People (petitioning system)',
#  'suriya': 'Suriya',
#  'xb2': 'Xbox 360',
#  'bollywood': 'Bollywood',
#  'middle class': 'Middle class',
#  'But not': 'For but not with',
#  'Long long way to go': 'Long, Long Way to Go',
#  'arnab_goswami': 'Arnab Goswami',
#  'karna': 'Karna',
#  'pata': 'Parallel ATA',
#  'Gangs of': 'Gangs of Wasseypur',
#  'Hindi cinema': 'Bollywood',
#  'matter': 'Matter (philosophy)',
#  'nWE': 'Yin Yin Nwe',
#  'BOLLYWOOD': 'Bollywood',
#  'Salman Khan': 'Salman Khan',
#  'India': 'India',
#  'Big': 'The Notorious B.I.G.',
#  'conspiracy': 'Conspiracy (criminal)',
#  'CBI': 'Central Bureau of Investigation',
#  'twitter': 'Twitter',
#  'truth': 'Truth',
#  'Not a day goes by': 'Not a Day Goes By',
#  'sushant': 'Rajan Sushant',
#  'people': 'Person',
#  't stop': 'F-number',
#  'gone too soon': 'Gone Too Soon',
#  'our own': 'On Our Own (1994 TV series)',
#  'beloved': 'Intimate relationship',
#  'pure soul': 'Pure Soul',
#  'Prayers': 'Prayer',
#  'family': 'Family',
#  'krke': 'KRKE',
#  'singh': 'Ranjit Singh',
#  'rajput': 'Rajput',
#  'nIs': 'Israeli new shekel',
#  'SMILE': 'Smile (Charlie Chaplin song)',
#  'godfather': 'The Godfather',
#  'power': 'Power (Kanye West song)',
#  'unity': '1 (number)',
#  'SUSHANT SINGH RAJPUT': 'Sushant Singh Rajput',
#  'RAJPUT': 'Rajput',
#  'xbc': 'XBC',
#  'tweeter': 'Twitter',
#  'ladai': 'István Ládai',
#  'khtm': 'KHTM-LP',
#  'we': 'Royal we',
#  'Maharashtra': 'Maharashtra',
#  'Pakistan': 'Pakistan',
#  'out for justice': 'Out for Justice',
#  'When we': 'When We On',
#  'When we are together': 'When We Are Together',
#  'will': 'Free will',
#  'do': 'Tao',
#  'time justice': 'A Time for Justice',
#  'God': 'God',
#  'inki': 'Inki',
#  'friends': 'Friendship',
#  'voices': 'Melody',
#  'answers': 'Answer',
#  'help': 'Help! (song)',
#  'word': 'Logos',
#  'inside job': 'Inside Job (2010 film)',
#  'Mafia': 'Mafia',
#  'Afzal guru': 'Afzal Guru',
#  'beautiful soul': 'Beautiful Soul (song)',
#  'nightsky': 'Nicklas Nygren',
#  'wale': 'Wale (rapper)',
#  'government of India': 'British Raj',
#  'kyon': 'An Gyeon',
#  'sushant singh rajput': 'Sushant Singh Rajput',
#  'jogger': 'Jogging',
#  'park': 'Park',
#  'chkd': "Children's Hospital of The King's Daughters",
#  'SUSHANT': 'Rajan Sushant',
#  'nIt': 'National Invitation Tournament',
#  'x87': 'X87',
#  'hue': 'Huế',
#  'alawa': 'Alawa',
#  'presense': 'PR-e-Sense',
#  'who': 'The Who',
#  'him': 'Imperial Majesty (style)',
#  'biggest loser': 'The Biggest Loser (U.S. TV series)',
#  'ab nai': 'Ab Nai',
#  'bhakti': 'Bhakti',
#  'ppl': 'Product placement',
#  'Hrithik Roshan': 'Hrithik Roshan',
#  'TL': 'Turkish lira',
#  'Krrish': 'Krrish',
#  't post': 'Steel fence post',
#  'milke': 'Debra Milke',
#  'ht': '.ht',
#  'ke': 'Ke (kana)',
#  'apke': 'Tom Apke',
#  'lekin': 'Lekin...',
#  'jla': 'Justice League',
#  'heartless': 'Heartless (Kanye West song)',
#  'STAR': 'Star',
#  'STARS': 'Star',
#  'n\\n': 'Nine Inch Nails',
#  'Nah': 'Or Nah (The Game song)',
#  'Nah nah': 'Loyalty and Betrayal (E-40 album)',
#  'nmake': 'Make (software)',
#  'Mahesh Bhatt': 'Mahesh Bhatt',
#  'Yes what': 'Yes, What?',
#  'x96': 'KXRK',
#  'harsh times': 'Harsh Times',
#  'kro': 'Katholieke Radio Omroep',
#  'hoti': 'Hoti (tribe)',
#  'toh': 'Terry Toh',
#  'sushant singh': 'Sushant Singh',
#  'sushant Singh Rajput': 'Sushant Singh Rajput',
#  'Ajay Devgan': 'Ajay Devgan',
#  'strong': 'Ken Strong',
#  'pakistani': 'Pakistan Army',
#  'pakistani ISI': 'Inter-Services Intelligence',
#  'ISI': 'Inter-Services Intelligence',
#  'ISI agent': 'Inter-Services Intelligence',
#  'a man': 'Military Intelligence Directorate (Israel)',
#  'man who': 'The Man Who',
#  'Army Commando': '3 Commando Brigade',
#  'Commando': 'British Commandos',
#  'hanging': 'Hanging',
#  'strangulation': 'Strangling',
#  'Retweet': 'Twitter',
#  'Bolywood': 'Bollywood',
#  'Globe': 'Globe',
#  'Thx': 'THX',
#  'Come back': 'My Way (Usher album)',
#  'because of you': 'Because of You (Kelly Clarkson song)',
#  'hindi': 'Hindi',
#  'Because of you': 'Because of You (Ne-Yo song)',
#  'i found u': 'I Found U',
#  'Yakub Memon': 'Yakub Memon',
#  'not like the movies': 'Not Like the Movies',
#  'Friends with benefits': 'Friends with Benefits (film)',
#  'hashtag': 'Hashtag',
#  'autofill': 'Autofill',
#  'amp;\\n': 'Oregon Railroad and Navigation Company',
#  'chingaari': 'Chingaari',
#  'Aag': 'Aag (2007 film)',
#  'india': 'India',
#  'Hit 1': 'Moy Hit 1',
#  'come together': 'Come Together',
#  'fight': 'Fight (band)',
#  'the power': 'The Power (Snap! song)',
#  'Patna': 'Patna',
#  'we the common': 'We the Common',
#  'common people': 'Commoner',
#  'good': 'Good and evil',
#  'strength': 'Courage',
#  'Maharashtra police': 'Maharashtra Police',
#  'shinning': 'Treehouse of Horror V',
#  'vain': 'In Vain (band)',
#  'xb3': 'Xbox One',
#  'burn out': 'Occupational burnout',
#  'CBi': 'Central Bureau of Investigation',
#  'today': 'Today (U.S. TV program)',
#  'emotion': 'Emotion',
#  'hamesha': 'Hameshaa',
#  'Akshay Kumar': 'Akshay Kumar',
#  'nHat': 'An Nhất',
#  'Karan Johar': 'Karan Johar',
#  'amd': 'Advanced Micro Devices',
#  'SHIVSENA': 'Shiv Sena',
#  'bhaiya': 'Chandrabhan Bhaiya',
#  'Mumbai': 'Chhatrapati Shivaji Terminus',
#  'Mumbai Police': 'Mumbai Police',
#  's Make It': "'S Make It",
#  'happiness': 'Happiness',
#  'FOREVER': 'Eternity',
#  'WILL': 'Will Smith',
#  'wake up India': 'Wake Up India',
#  'nNow': 'Mikkel Rønnow',
#  'maharastra': 'Maharashtra',
#  'justice ......peace': 'Pontifical Council for Justice and Peace',
#  'peace': 'Peace',
#  'when we': 'When We On',
#  'days are numbered': 'His Days Are Numbered',
#  "I'm happy": 'Happy (Pharrell Williams song)',
#  'happy': 'Happiness',
#  'MAFIA': 'Mafia (1993 film)',
#  'Justice': 'Justice',
#  'made man': 'Made man',
#  'Nepotism': 'Nepotism',
#  'photon': 'Photon',
#  'suicide': 'Suicide',
#  'fake': 'Forgery',
#  'depression': 'Major depressive disorder',
#  'yes it is': 'Yes It Is',
#  'bollywood hero': 'Bollywood Hero',
#  'hope.. Justice': 'Hope for Justice',
#  'Mumbai police': 'Mumbai Police',
#  'heart': 'Heart (band)',
#  'tweeting': 'Twitter',
#  'nit': 'Head louse',
#  'candles': 'Candle',
#  'candle': 'Candle',
#  'se': 'Societas Europaea',
#  'bohot': 'Bohot',
#  'Omg': 'Yahoo! News',
#  'Sushant Singh': 'Sushant Singh',
#  'brighter day': 'The Brighter Day',
#  'Stand': "JoJo's Bizarre Adventure",
#  'Sir': 'Sir',
#  'Akshay Khanna': 'Akshaye Khanna',
#  'innocent': 'Innocence',
#  'CCTV': 'Closed-circuit television',
#  'bathrobe': 'Robe',
#  'belt': 'Belt (clothing)',
#  'stool': 'Chair',
#  'chair': 'Chair',
#  'room :Mystery': 'Room - The Mystery',
#  'hospitals': 'Hospital',
#  'Twitter': 'Twitter',
#  'the party': 'Triumph Heritage Empowerment Party',
#  'You': 'With You (Jessica Simpson song)',
#  'true love': 'Romance (love)',
#  'trending': 'Twitter',
#  's make it': "'S Make It",
#  'to show': 'The T.O. Show',
#  'Canada': 'Canada',
#  'nHar': 'Ningxia',
#  'Soul': 'Soul',
#  'Will': 'Will and testament',
#  'hashtags': 'Hashtag',
#  'more &amp; more': 'More &amp; More',
#  'social media': 'Social media',
#  'mental illness': 'Mental disorder',
#  'Bhaiyaa': 'Bhaiyaa',
#  'sacrifice': 'Sacrifice',
#  'Kaise': 'Sōsuke Kaise',
#  'Sushant singh rajput': 'Sushant Singh Rajput',
#  'gangsters': 'Yakuza',
#  'murderers': 'Murder',
#  'now': 'Present',
#  'watch': 'Watch',
#  'Singh': 'Veer Singh (politician)',
#  'Goverment': 'Government',
#  'Subramanian Swamy': 'Subramanian Swamy',
#  'Thank u': 'Thank U For',
#  'normal': 'Normality (behavior)',
#  'boycott': 'Election boycott',
#  'lobby': 'Lobbying',
#  'advertising': 'Advertising',
#  'death': 'Death',
#  'murder': 'Murder',
#  'u. u': 'Unitarian Universalism',
#  'Sharukh Khan': 'Shah Rukh Khan',
#  'nMake': 'Make (software)',
#  'Film Release': 'Film release',
#  'Pehle': 'Walter H. Pehle',
#  "nI'm": 'Nishan-e-Imtiaz',
#  'baten': 'Batin (Islam)',
#  'nnow': 'Mikkel Rønnow',
#  'come on India': 'Chak De! India',
#  'end': 'To the End (Blur song)',
#  'life': 'Life',
#  'punished': 'Punishment',
#  'always': 'Always (Bon Jovi song)',
#  'truth prevails': 'Truth prevails',
#  'xb0': 'Degree symbol',
#  'favoritism': 'Ingroups and outgroups',
#  '3 Ft': '3 ft gauge railways',
#  'nFan': 'Friendship graph',
#  'Rope': 'Rope',
#  'Ceiling': 'Ceiling',
#  'protest': 'Protest song',
#  'seperate video': 'S-Video',
#  'Rhea chakraborty': 'Rhea Chakraborty',
#  'shameless': 'Shameless (UK TV series)',
#  'ankh': 'Ankh',
#  'jai ho': 'Jai Ho (song)',
#  'sympathizer': 'The Sympathizer',
#  'You were': 'You Were...',
#  'Silent Scream': 'The Silent Scream',
#  'to light a candle': 'To Light a Candle',
#  'Allah': 'God in Islam',
#  'sins': 'Sin',
#  'agni': 'Agni',
#  'kripa': 'Kripa',
#  'love': 'Love (band)',
#  'Sanjay Dutt': 'Sanjay Dutt',
#  'Shetty': 'Rohit Shetty',
#  'Khan': 'Nusrat Fateh Ali Khan',
#  'Devgan': 'Ajay Devgan',
#  'screen': 'Kayfabe',
#  'memories of you': 'Memories of You',
#  'for a moment': 'For a Moment (album)',
#  'moment': 'For a Moment (album)',
#  'n so': 'Nıso',
#  'humans': 'Human',
#  'emotions': 'Emotion',
#  'paisa paisa': 'Paisa Paisa (film)',
#  'Bihar': 'Bihar',
#  'central government': 'Central government',
#  'ge': 'General Electric',
#  'dikta': 'Dikta',
#  'aankhen': 'Aankhen (1993 film)',
#  'Rajeev Masand': 'Rajeev Masand',
#  'tweets': 'Twitter',
#  'Terrorist': 'Terrorism',
#  'B-Town': 'B-Town',
#  'MYSTERY': 'Sacred mysteries',
#  'Insaaf': 'Insaaf (1987 film)',
#  'hum': 'Hum (film)',
#  'pressure': 'Pressure',
#  'wherever you are': 'Wherever You Are (Military Wives song)',
#  'we ll get': "We'll Get By",
#  'x99': 'Intel X99',
#  'Puri': 'Puri',
#  'Tathastu': 'Tathastu',
#  'not giving': 'Not Giving In',
#  'movie': 'MASH (film)',
#  'pray': 'Prayer',
#  'fair': 'Justice',
#  'evil': 'Evil',
#  'bucket list': 'The Bucket List',
#  'hui': 'Hui people',
#  'usme': 'Maine',
#  'kangana Ranaut': 'Kangana Ranaut',
#  'Queen': 'Queen (film)',
#  'one man army': 'One Man Army (band)',
#  'Akshay khanna': 'Akshaye Khanna',
#  'sir': 'Sir',
#  'us': 'United States dollar',
#  'youtube': 'YouTube',
#  'polythene': 'Polyethylene',
#  'polythene bag': 'Polyethylene',
#  'action.\\n': 'Operation N',
#  'Sushant Singh rajput': 'Sushant Singh Rajput',
#  'on fire': 'On Fire (Lil Wayne song)',
#  'Raise Your Voice': 'Raise Your Voice',
#  'murdered': 'Assassination of Martin Luther King, Jr.',
#  'Light': 'Light',
#  'th': 'Thorium',
#  'to win': 'Tołwin',
#  'love you': 'Love You To',
#  'Retweeted': 'Twitter',
#  'verified': 'Twitter',
#  'us  ma': 'Massachusetts',
#  'Govt': 'Government of India',
#  'Abu Salem': 'Abu Salem',
#  'deshdrohi': 'Deshdrohi',
#  'with you': 'With You (Jessica Simpson song)',
#  'burn': 'Burn',
#  'burning for you': 'Burning for You',
#  'darkness': 'The Darkness (band)',
#  'Sorry': 'Sorry (Madonna song)',
#  'koyi': "Patrick N'Koyi",
#  'person': 'Human',
#  'khan': 'Nusrat Fateh Ali Khan',
#  'akshay kumar': 'Akshay Kumar',
#  'saw u': 'Saw u',
#  'spam': 'Spamming',
#  'shine': 'Shine (Collective Soul song)',
#  'barbad': 'Barbad',
#  'Karma': 'Karma',
#  'youth of today': 'Youth of Today',
#  'Photon': 'Monica Rambeau',
#  'double slit': 'Double-slit experiment',
#  'nAre': 'Nostril',
#  'sim card': 'Subscriber identity module',
#  'Arnab Goswami': 'Arnab Goswami',
#  'all rounder': 'All-rounder',
#  'human being': 'Human',
#  'Boston': 'Boston (band)',
#  'Shall we': 'Shall We Dance? (1996 film)',
#  'my hero': 'My Hero (UK TV series)',
#  'ladaai': 'Ladaai',
#  'lalkaar': 'Lalkaar',
#  'nSab': 'SES Sirius',
#  'Mahesh Shetty': 'Mahesh Shetty',
#  'thanks': 'Gratitude',
#  'do it': 'For You (Selena Gomez album)',
#  'sushanth': 'Sushanth',
#  'whole truth': 'The Whole Truth (TV series)',
#  'Justice delayed is justice denied': 'Justice delayed is justice denied',
#  'give birth': 'Childbirth',
#  'birth': 'Childbirth',
#  'all family': 'All in the Family',
#  'hope Die': 'And Hope to Die',
#  'Actress': 'Actor',
#  'Actors': 'Actor',
#  'light': 'Light',
#  'after Life': 'Afterlife',
#  'down One': 'Down for the One',
#  'underworld': 'Underworld (film series)',
#  'nCan': 'Neurocan',
#  'Him': 'HIM (Finnish band)',
#  'Come Up': 'J. Cole',
#  'a bad': 'Aurangabad, Maharashtra',
#  'vested': 'Vesting',
#  'vested interest': 'Vesting',
#  'support': 'Sympathy',
#  'ne hi': 'NE-HI',
#  'Kangana Ranaut': 'Kangana Ranaut',
#  'binding': 'Contract',
#  'binding contract': 'Contract',
#  'contract': 'Contract',
#  'individual': 'Individual',
#  'love can do that': 'Love Can Do That',
#  'nCBI': 'National Center for Biotechnology Information',
#  'fake police': 'Police impersonation',
#  'energy': 'Energy',
#  'sushant Singh rajput': 'Sushant Singh Rajput',
#  'World': 'World',
#  'if': 'If (Janet Jackson song)',
#  'you': 'With You (Chris Brown song)',
#  'play it': 'Play.it',
#  'government': 'Government of India',
#  'cbi': 'Central Bureau of Investigation',
#  'peaceful revolution': 'Peaceful Revolution',
#  'why': 'Why? (American band)',
#  'VOICE': 'The Voice (Mike Jones album)',
#  'time': 'Time signature',
#  'umask': 'Umask',
#  "we'll get": "We'll Get By",
#  'fish': 'Fish',
#  'just GOD': 'God',
#  'Alia bhatt': 'Alia Bhatt',
#  'dilana': 'Dilana',
#  'x86': 'X86',
#  'dosto': 'Bilevel rail car',
#  'kyun ki': 'Kyon Ki',
#  'Copy &amp; Paste': 'Cut, copy, and paste',
#  'candle march': 'Candlelight vigil',
#  're tweet': 'Twitter',
#  'Yash Chopra': 'Yash Chopra',
#  'We all together': 'We All Together',
#  'Akshay kumar': 'Akshay Kumar',
#  'karmo': 'Alex Karmo',
#  'last day of my life': 'Last Day of My Life',
#  'must be feeling': 'Must Be the Feeling',
#  'Silence': 'Barfi!',
#  'acceptance': 'Acceptance',
#  'End': 'In the End',
#  'tak': 'Desperation (novel)',
#  'nLets': 'Law enforcement in the United States',
#  'action b': 'German AB-Aktion in Poland',
#  'Singapore': 'Singapore',
#  'feel': 'Feel (Robbie Williams song)',
#  'one god': 'God',
#  'god': 'God',
#  'i will pray': 'I Will Pray (Pregherò)',
#  'favouritism': 'Elitism',
#  'abiut': 'Roger Abiut',
#  'action? \\n': 'Operation N',
#  'Ganesha': 'Ganesha',
#  'now hear': 'Here and Nowhere Else',
#  'now hear this': 'Now Hear This (Duke Pearson album)',
#  'xe2': 'Fujifilm X-E2',
#  'xa1': 'Fujifilm X-A1',
#  'laws': 'Statutory law',
#  'Arrogant': 'Pride',
#  'sakib': 'Sakib',
#  'WordPress': 'WordPress',
#  'Fiverr': 'Fiverr',
#  'Myanmar': 'Myanmar',
#  'don': 'Don River (Russia)',
#  'bolenge': 'Bolenge',
#  'human': 'Human',
#  'faith': 'Faith',
#  'constitution': 'Constitution',
#  'injustice': 'Justice',
#  'krna': 'KRNA',
#  'nwe': 'Yin Yin Nwe',
#  'pandemic': 'Epidemiology of HIV/AIDS',
#  'nation': 'The Nation',
#  'industry': 'Music industry',
#  'xad': 'XAD (software)',
#  'iss': 'International Space Station',
#  'chuki': 'Sonam Chuki',
#  'God exists': 'Existence of God',
#  'lao': 'Laos',
#  'parents': 'Parent',
#  'running': 'United States Senate election in North Carolina, 2014',
#  'running around': 'Running',
#  'Sushanth': 'Sushanth',
#  'loys': 'Charles de Loys',
#  'take that': 'Take That',
#  'thing': 'Object (philosophy)',
#  'mind': 'Mind',
#  'nAbhi': 'Nabhi',
#  'tonight': 'Tonight (1957 TV series)',
#  'd case': 'The D Case',
#  'Tgis': 'T.G.I.S.',
#  'Truth': 'Truth',
#  'still blind': 'Still Blind',
#  'until we win': 'Channel Awesome',
#  'but not': 'For but not with',
#  'moon': 'Moon',
#  'ncase': 'National Congress on Aviation and Space Education',
#  'hitnrun': 'Hit n Run Phase One',
#  'Maine': 'Maine',
#  'spne': 'Subgame perfect equilibrium',
#  'Laddu': 'Laddu',
#  'Sushant singh Rajput': 'Sushant Singh Rajput',
#  'remain in our hearts': 'Remain in Our Hearts (DJ Hidrro song)',
#  'locksmith': 'Lock (security device)',
#  'botch': 'Botch (band)',
#  'transfer case': 'Transfer case',
#  'slap': 'Professional wrestling attacks',
#  'haters': 'The Thomaselli Brothers',
#  'ho sakta hai': 'Ho Sakta Hai',
#  'judiciary': 'Judiciary',
#  'INDIA': 'India',
#  'HINDUS': 'Hindu',
#  'PAKISTAN': 'Pakistan',
#  'miss out': 'Elimination races',
#  'nKya': 'Lucy Nkya',
#  'daala': 'Daala',
#  'bhandari': 'Bhandary',
#  'thank u': 'Thank U',
#  'Mukim': 'Mukim',
#  'every thing': 'The Great Northwest',
#  'Sooraj Pancholi': 'Hero (2015 Hindi film)',
#  'nMy': 'Text messaging',
#  'Fear': 'The Fear (Lily Allen song)',
#  'kbhi': 'KBHI',
#  'hatya': 'Hatya',
#  'Divya bharti': 'Divya Bharti',
#  '12 AM': '12-hour clock',
#  'salman khan': 'Salman Khan',
#  'punish': 'Punishment',
#  'guilty': 'Guilty (Blue song)',
#  'investigation': 'Criminal procedure',
#  'evidence': 'Evidence (law)',
#  "it's time": "It's Time (Imagine Dragons song)",
#  'nTop': 'Ntop',
#  'wishes': 'Wish',
#  'We are': 'We Are (Ana Johnsson song)',
#  'my world': 'My World (EP)',
#  'nDey': 'Rudy Ndey',
#  'nNd': 'Niconico',
#  'Raise your voice': 'Raise Your Voice',
#  'Why': 'Why (Mary J. Blige song)',
#  'u should': '10 (LL Cool J album)',
#  'tycoon': 'Business magnate',
#  'shakuni': 'Shakuni',
#  'Krishna': 'Krishna',
#  'shine forever': 'Shine On Forever (Photo Frame)',
#  't Stop': 'F-number',
#  'dil se': 'Dil Se..',
#  'accused': 'Indictment',
#  'Tweeter': 'Twitter',
#  'pehle': 'Walter H. Pehle',
#  'khatra': 'Khatra',
#  'maharashtra': 'Maharashtra',
#  'jst': 'Japan Standard Time',
#  'paisa': 'Paisa',
#  'Cbi': 'Central Bank of India',
#  'Superhero': 'Superhero film',
#  "b'wood": 'Albert Beaumont Wood',
#  'Maharastra': 'Maharashtra',
#  'hindu': 'Hinduism',
#  'I am': 'I Am... Sasha Fierce',
#  'Legends never die': 'Legends Never Die (R.A. the Rugged Man album)',
#  'patience': 'Patience',
#  'anger': 'Anger',
#  'Yhi': 'Yhi',
#  'actors': 'Actor',
#  'actress': 'Actor',
#  'JNU': 'Jawaharlal Nehru University, Delhi',
#  'better you': 'Better with You',
#  'wanted': 'The Wanted',
#  'tomorrow': 'Tomorrow (Sean Kingston album)',
#  'sabne': 'Subhash Piraji Sabne',
#  'kaash': 'Kaash',
#  'nI': 'Nine Inch Nails',
#  'wonder': 'Stevie Wonder',
#  'stay': 'Stay (Shakespears Sister song)',
#  'yo': 'Yo (Excuse Me Miss)',
#  'right now': 'Right Now (Korn song)',
#  'terrorist': 'Terrorism',
#  'Suicide': 'Suicide',
#  'ur': 'Ur',
#  'film': 'Film',
#  'live': 'Live (band)',
#  'nehi': 'Nehi',
#  'Evry': 'Évry, Essonne',
#  'to see you': 'To See You',
#  'see you': 'To See You',
#  'Oh ok': 'Oh-OK',
#  'mentor': 'Mentorship',
#  'Rhea': 'Rhea (bird)',
#  'nJai': 'Njai',
#  'MUMBAI': 'Mumbai',
#  'MUMBAI POLICE': 'Mumbai Police',
#  'OMBLE': 'Tukaram Omble',
#  'Candle': 'Candle',
#  'muh': 'Robert A. Muh',
#  'Yes... Please': 'Yes Please!',
#  'thier': 'Samuel O. Thier',
#  'Indian cinema': 'Cinema of India',
#  'love &amp;respect': 'Love &amp; Respect',
#  'Last Rites': 'Last rites',
#  'always and forever': 'Always and Forever (Heatwave song)',
#  'Big B': 'Big B (rapper)',
#  'B as': 'Bachelor of Asian Studies',
#  'nI had': 'Niðhad',
#  'Nothing': 'Nothing',
#  'Facebook': 'Facebook',
#  'Instagram': 'Instagram',
#  'YouTube': 'YouTube',
#  'WhatsApp': 'WhatsApp',
#  'Suraj Pancholi': 'Hero (2015 Hindi film)',
#  'sorry': 'Sorry (Madonna song)',
#  'am': 'Master of Arts',
#  'love never dies': 'Love Never Dies (musical)',
#  'Beautiful soul': 'Beautiful Soul (song)',
#  'HIT 1': 'Moy Hit 1',
#  'kind': 'Kind (type theory)',
#  "who's": 'The Who',
#  'Cooper hospital': 'Cooper Hospital',
#  'right thing': 'Ethics',
#  'mentally': 'Psychological abuse',
#  'depressed': 'Depression (mood)',
#  'matrix world': 'Simulation',
#  'big': 'The Notorious B.I.G.',
#  'names': 'Stage name',
#  'we want': 'We Want In: The Street LP',
#  'out': 'Out (magazine)',
#  'open': 'Open vowel',
#  'up. people': 'Up with People',
#  'brave': 'Brave (2012 film)',
#  "who\\'s": 'The Who',
#  'Rishi kapoor': 'Rishi Kapoor',
#  'KARZ': 'Karz (film)',
#  'rha': 'Royal Horse Artillery',
#  'TOH': 'Terry Toh',
#  'young India': 'Young India',
#  'Bravo': 'Bravo (U.S. TV network)',
#  'twitterati': 'Twitter',
#  'agr': 'Advanced gas-cooled reactor',
#  'awaz': 'Awaz',
#  'cases': 'Precedent',
#  'Amir khan': 'Amir Khan (boxer)',
#  'NASA': 'NASA',
#  'trip to the moon': 'A Trip to the Moon',
#  'ma': 'Master of Arts',
#  'pure souls': 'The Pure Souls',
#  'precious gem': 'Gemstone',
#  'gem': 'Gemstone',
#  'answer': 'The Answer (band)',
#  'you were': 'You Were...',
#  'live forever': 'Immortality',
#  'public': 'Public',
#  'public places': 'Public space',
#  'rajpoot': 'Rajput',
#  'murders': 'Murder',
#  'sherni': 'Sherni',
#  'italy': 'Italy',
#  'chabra': 'Ajay Chabra',
#  'mukesh': 'Mukesh (actor)',
#  'act': 'Act of Parliament',
#  'the chain': 'The Chain (Buffy comic)',
#  'Sushi': 'Sushi',
#  'she is one': 'S.H.E is the One',
#  'democracy': 'Democracy',
#  'all will succeed': 'Outcome-based education',
#  'think small': 'Think Small',
#  'unexpected': 'Unexpected (Heroes)',
#  'heroes': 'Heroes (2008 film)',
#  'one': 'One (U2 song)',
#  'nHis': 'New Hampshire Motor Speedway',
#  'double-slit': 'Double-slit experiment',
#  'koshish': 'Koshish',
#  'channel': 'Channel (communications)',
#  'paid media': 'Advertising',
#  'SSRI': 'Selective serotonin reuptake inhibitor',
#  'our feelings': 'And Our Feelings',
#  'Fair': 'Justice',
#  'case': 'Precedent',
#  'dog': 'Dog',
#  'Deepika padukone': 'Deepika Padukone',
#  'Ranveer Singh': 'Ranveer Singh',
#  'pakistan': 'Pakistan',
#  'karma': 'Karma',
#  'Please': 'Please (Pet Shop Boys album)',
#  't sign': 'Monochorionic twins',
#  'patent': 'Patent',
#  'patent right': 'Patent',
#  'innovation': 'Innovation',
#  'designing': 'Design',
#  'no one': 'No One (Alicia Keys song)',
#  'join with us': 'Join With Us (album)',
#  'in this moment': 'In This Moment',
#  'nkisi': 'Nkisi',
#  'singham': 'Singham',
#  'sirf': 'SiRF',
#  'dhanki': 'Khandeshi language',
#  'rokne': 'Marianne Rokne',
#  'South Africa': 'South Africa',
#  'then you': "The Beatles' Christmas records",
#  'afzal guru': 'Afzal Guru',
#  'rhea chakraborty': 'Rhea Chakraborty',
#  'Aditya roy kapur': 'Aditya Roy Kapur',
#  'and R \\n': 'Andırın',
#  'Hit and Run': 'Hit and Run (Girlschool album)',
#  'keeping mum': 'Keeping Mum',
#  'Tweets': 'Twitter',
#  'Retweets': 'Twitter',
#  'Jeet': 'Jeet (1996 film)',
#  'everytime': 'Everytime',
#  'iridescence': 'Iridescence',
#  'etching': 'Etching (microfabrication)',
#  'Hope Justice': 'Hope for Justice',
#  'promise': 'The Promise (Bruce Springsteen album)',
#  'pain': 'Suffering',
#  'threat': 'Coercion',
#  'society': 'Society',
#  'BJP': 'Bharatiya Janata Party',
#  'aneel mussarat': 'Aneel Mussarat',
#  'anti india': 'Anti-Indian sentiment',
#  'Canadian': 'Canadians',
#  'Pakistani': 'Cinema of Pakistan',
#  'Pakistani ISI': 'Inter-Services Intelligence',
#  'gaya': 'Gaya, India',
#  'canadian': 'Canada',
#  'play dirty': 'Play Dirty',
#  'dirty game': 'The Dirty Game',
#  'justice Or else': '20th Anniversary of the Million Man March: Justice or Else',
#  'Kapil Sharma': 'Kapil Sharma (comedian)',
#  'speak now': 'Speak Now',
#  'Candle in the Wind': 'Candle in the Wind',
#  'Wind': 'Wind',
#  'fight for you': 'Fight for You',
#  'England': 'England national football team',
#  'thank you': 'Thank You (Busta Rhymes song)',
#  'above law': 'Above the Law (group)',
#  'interrogation': 'Interrogation',
#  'right': 'Rights',
#  'facts': 'Fact',
#  'Why dont you': "Why Don't You?",
#  'Jus': 'Canon law (Catholic Church)',
#  'lockdown': 'Lockdown',
#  'villains': 'Heel (professional wrestling)',
#  'akela': 'Akela (Jungle Book)',
#  'Yash Raj films': 'Yash Raj Films',
#  'without you': 'Without You (Badfinger song)',
#  'actor &amp; actress': 'Actor',
#  'Naseer': 'Ahmed Naseer',
#  'humanity': 'Human rights',
#  'sun li': 'Sun Li (Water Margin)',
#  'thali': 'Thali',
#  'Wale': 'Wale (rapper)',
#  'Lanka Dahan': 'Lanka Dahan',
#  'alia Bhatt': 'Alia Bhatt',
#  'chote': 'Morville Chote',
#  'twits': 'The Twits',
#  'media': 'Media (communication)',
#  'media coverage': 'Mass media',
#  'me': 'Me (kana)',
#  'Dirty Politics': 'Dirty Politics',
#  'Dawood Ibrahim': 'Dawood Ibrahim',
#  'Shakeel': 'Chhota Shakeel',
#  'rave party': 'Rave',
#  'Nation': 'Nation',
#  'ms dhoni': 'Mahendra Singh Dhoni',
#  'kaise': 'Sōsuke Kaise',
#  'biopic': 'Biographical film',
#  'm so': 'Sociology',
#  'Young India': 'Young India',
#  'We will overcome': 'We Will Overcome (album)',
#  'will overcome': 'War of Will',
#  'gangs of': 'Gangs of Wasseypur',
#  'krk': 'Krk',
#  'nhi': 'Đàn nhị',
#  'ho': 'Holmium',
#  'Revolt': 'Revolution',
#  'object': 'Entity',
#  'Sushant  Singh Rajput': 'Sushant Singh Rajput',
#  't  stop': 'F-number',
#  'Murder': 'Murder',
#  'killer': 'Murder',
#  'Sushant singh': 'Sushant Singh',
#  'Kids': 'Child',
#  'Bombay': 'Bombay (film)',
#  'Bombay police': 'Mumbai Police',
#  'lynching': 'Lynching',
#  'sadhus': 'Sadhu',
#  'Bombay Police': 'Mumbai Police',
#  'amp': 'The Amp',
#  'negligence': 'Negligence',
#  'Investigation': 'Criminal procedure',
#  'police': 'Police',
#  'Y not': 'Y Not',
#  'IIT Powai': 'Indian Institute of Technology Bombay',
#  'Powai': 'Powai',
#  'demand': 'Supply and demand',
#  'policeman': 'Police officer',
#  'nPower': 'RWE npower',
#  'Dosto': 'Bilevel rail car',
#  'standing': 'Standing army',
#  'modi': 'Narendra Modi',
#  'shri ram': 'Rama',
#  'ram': 'Rama',
#  'ray': 'Ray (film)',
#  'convicted': 'Conviction',
#  'Italy': 'Italy',
#  'you are so beautiful': 'You Are So Beautiful',
#  'tq': 'TQ (singer)',
#  'hope justice': 'Hope for Justice',
#  'Om': 'Om',
#  'Om shanti': 'Mantra',
#  "you're a STAR": "You're a Star",
#  'TILL THE END OF TIME': 'Till the End of Time (song)',
#  'lighting': 'Lighting',
#  'isi': 'Institute for Scientific Information',
#  'terrorist activities': 'Terrorism',
#  'punishable': 'Punishment',
#  'hails': 'Robert Hails',
#  'power of love': 'The Power of Love (Jennifer Rush song)',
#  'love &amp; truth': 'Love &amp; Truth',
#  'SUICIDE': 'Suicide',
#  'hmara': 'Bou Hmara',
#  'real': 'Reality',
#  'pahle': 'Tone Pahle',
#  'Hum log': 'Hum Log (TV series)',
#  'ummid': 'Kiya Buzurg Ummid',
#  'like a prayer': 'Like a Prayer (song)',
#  'peaceful': 'Peace',
#  'democratic': 'Democracy',
#  'Public domain': 'Public domain',
#  'bhrikuti': 'Bhrikuti',
#  'whats': "WHATS'On (Software)",
#  'felate': 'Fellatio',
#  'Auto suggestion': 'Autosuggestion',
#  "it's for you": "It's for You",
#  'angel boy': 'Angel Boy',
#  'retweeting': 'Reblogging',
#  'hit 1': 'Moy Hit 1',
#  'crime': 'Crime',
#  'jihadists': 'Mujahideen',
#  'nexus': 'Process philosophy',
#  'break': 'Break (music)',
#  'Shame': 'Shame',
#  'kumar': 'Amitava Kumar',
#  'forever in my heart': 'Forever in My Heart',
#  'karachi': 'Karachi',
#  'fir': 'Flight information region',
#  'dunga': 'Dunga',
#  'self': 'Philosophy of self',
#  'thoughts': 'Thought',
#  'jayega': 'Hum Jayega',
#  'nAs': 'National Academy of Sciences',
#  'running for': 'United States Senate election in North Carolina, 2014',
#  'mainstream media': 'Mass media',
#  'whole World is watching': 'Whole World Is Watching',
#  'A man': 'Military Intelligence Directorate (Israel)',
#  'Salman khan': 'Salman Khan',
#  'indian army': 'Indian Army',
#  'snatch': 'Snatch (film)',
#  'YES': 'Yes (band)',
#  'UPA': 'United Progressive Alliance',
#  'UPA government': 'United Progressive Alliance',
#  'dirty mind': 'Dirty Mind',
#  'Alia Bhatt': 'Alia Bhatt',
#  'BlacklivesMatter': 'Black Lives Matter',
#  'isi agent': 'Inter-Services Intelligence',
#  'try': 'Trial',
#  'burning': 'Fire',
#  'nai': 'Sodium iodide',
#  'bht': 'Butylated hydroxytoluene',
#  'yash raj films': 'Yash Raj Films',
#  'films': 'Film',
#  'manoj kumar': 'Manoj Kumar',
#  'Mohd Rafi': 'Mohammed Rafi',
#  'prem patra': 'Prem Patra',
#  'God bless you': 'God bless you',
#  'bless you': 'God bless you',
#  'rich': 'Wealth',
#  'evil people': 'Evil',
#  'Threateners': 'The Threateners',
#  'diya': 'Diya (lamp)',
#  'Meena': 'Meena (actress)',
#  'Ankita lokhande': 'Ankita Lokhande',
#  'kabul': 'Kabul',
#  'bringing people together': '1992 Los Angeles riots',
#  'was MURDERED': 'Assassination of Olof Palme',
#  'Karan johar': 'Karan Johar',
#  "We're in this together": "We're in This Together",
#  'let it be': 'Let It Be (song)',
#  'Right': 'Rights',
#  'valid': 'Validity',
#  'question': 'Question (The Moody Blues song)',
#  'rope': 'Rope',
#  'army commando': '3 Commando Brigade',
#  'commando': 'British Commandos',
#  'astro-physics': 'Astrophysics',
#  'Sherlock Holmes': 'Sherlock Holmes',
#  'head\\n': 'Head On (video game)',
#  'never forget': 'Never Forget (Take That song)',
#  'your beautiful': "You're Beautiful",
#  'smile': 'Smile (Lily Allen song)',
#  'west': 'Western Europe',
#  'middle east': 'Middle East',
#  'entertainment': 'Entertainment',
#  'movies': 'Film',
#  'nationalism': 'Nationalism',
#  "We can't be stopped": "We Can't Be Stopped",
#  'Together we stand': 'Together We Stand',
#  'murder of one': 'A Murder of One',
#  'good trouble': 'Good Trouble',
#  'John Lewis': 'John Lewis (pianist)',
#  'ED': 'Enforcement Directorate',
#  'IB': 'Intelligence Bureau (India)',
#  'Remember': 'Memory',
#  'thm': 'Master of Theology',
#  'Kaash': 'Kaash',
#  'paate': 'Paate',
#  'Bohot': 'Bohot',
#  "I don't want to": "I Don't Want To",
#  'to your love': 'When the Pawn...',
#  'your love': 'When the Pawn...',
#  'Superstars': 'Superstars',
#  'bloody': 'Hematuria',
#  'bitch': 'Durham Red',
#  'child': 'Child',
#  'children': 'Child',
#  'thc': 'Tetrahydrocannabinol',
#  'day by day': 'Day by Day (TV series)',
#  'amp; \\n': 'Oregon Railroad and Navigation Company',
#  'janta ki Adalat': 'Janta Ki Adalat (1994 film)',
#  'Sandeep Singh': 'Sandeep Singh',
#  'candle March': 'Candlelight vigil',
#  'high time': 'High Time (film)',
#  '100%. Am': 'Distances shorter than 1 pm',
#  'came out': 'Coming out',
#  'seperation': 'A Separation',
#  'Justice delayed is Justice Denied': 'Justice delayed is justice denied',
#  'Good is': 'Good Worldwide',
#  'true': 'Truth',
#  'sukh': 'Sukhdeep Sukh',
#  'n\\n\\n': 'Azide',
#  'bad karma': 'Karma',
#  'TV Series': 'Television program',
#  'hope for Justice': 'Hope for Justice',
#  'dawood Ibrahim': 'Dawood Ibrahim',
#  'if this goes': 'If This Goes On—',
#  'Please please please': 'Please, Please, Please',
#  'nIts': 'National Invitation Tournament',
#  'In the heart of everyone': 'In the Heart of Everyone',
#  "B'wood": 'Albert Beaumont Wood',
#  'duty': 'Duty',
#  'extended family': 'Extended family',
#  'issue': 'Social issue',
#  'national': 'Nation',
#  'Dr': 'Doctor (title)',
#  'Movement': 'New religious movement',
#  'tarika': 'Tarika (musical group)',
#  'watch dis': 'Definition of Real',
#  'dupatta': 'Dupatta',
#  'Phoenix': 'Phoenix Suns',
#  'Middle Class': 'Middle class',
#  'Youth': 'Youth',
#  'Jhansi ki Rani': 'Jhansi Ki Rani (TV series)',
#  'ke Family': 'KE family',
#  'Mukesh Bhatt': 'Mukesh Bhatt',
#  'Parveen Babi': 'Parveen Babi',
#  'takle': 'Barry Takle',
#  'Do It': 'Do It (Nelly Furtado song)',
#  'inhumans': 'Inhumans',
#  'behind bars': 'Prison',
#  'in Real Life': 'Real life',
#  'Real Life': 'In Real Life',
#  'breathe': 'Breathe (Fabolous song)',
#  'breathe in': 'Breathe In (film)',
#  'Hope justice': 'Hope for Justice',
#  'Hindustani': 'Hindi',
#  'IPL': 'Booting',
#  'KKR': 'Kohlberg Kravis Roberts',
#  'Dubai': 'Dubai',
#  'B R Chopra': 'Baldev Raj Chopra',
#  ...}

# %%
replaced_tweets = []
for i,r in annotation_df.iterrows():
    tweet_words = r['Tweet'].strip().split(' ')
    for j in tweet_words:
        try:
            pass

# %% [markdown]
# # Lexicons

# %%
unigram_df = pd.read_csv('LEXICON_UG.txt', sep = " ")
unigram_df['sentiment'] = np.where(unigram_df['SENTIMENT_SCORE'] > 0, 1, 0)  # 1 is positive, 0 is negative
print(unigram_df.head())

# Create dict with unigram and sentiment
unigram_sentiment_dict = pd.Series(unigram_df.SENTIMENT_SCORE.values,
                                   index=unigram_df.UNIGRAM.values).to_dict()


bigrams_df = pd.read_csv( 'LEXICON_BG.txt', sep=" ")

# Add sentiment column
bigrams_df['sentiment'] = np.where(bigrams_df['SENTIMENT_SCORE'] > 0, 1, 0)  # 1 is positive, 0 is negative
bigrams_df.head()

bigram_sentiment_dict = pd.Series(
    bigrams_df.SENTIMENT_SCORE.values,
    index=bigrams_df.BIGRAM.str.split('-').apply(
        lambda l: tuple(l)
    )
).to_dict()
# Out:
#   UNIGRAM  SENTIMENT_SCORE  sentiment
# 0      aa         0.019674          1
# 1     aaa         0.032775          1
# 2    aaas         0.074593          1
# 3  aachen         0.011926          1
# 4     aah         0.118070          1

# %% [markdown]
# ### Reading adjective classes

# %%
xls_file = pd.ExcelFile('ADJECTIVES.xlsx', engine = 'openpyxl')
# print(xls_file.head())

adjective_expansion = pd.read_excel(xls_file, 'ADJECTIVE_EXPANSION').dropna(how='all').reset_index(drop=True)
high_low_PN = pd.read_excel(xls_file, '(HIGH,LOW)_POS_NEG', header=None)[0].values.tolist()
high_low_NP = pd.read_excel(xls_file, '(HIGH,LOW)_NEG_POS', header=None)[0].values.tolist()
fast_slow_PN = pd.read_excel(xls_file, '(FAST,SLOW)_POS_NEG', header=None)[0].values.tolist()
fast_slow_NP = pd.read_excel(xls_file, '(FAST,SLOW)_NEG_POS', header=None)[0].values.tolist()


def clean_adjective_df(df):
    adjectives = []
    for i in range(4):
        adjectives.extend(df.iloc[:, i+1].dropna().tolist())
    
    adj_category = df.iloc[0,0]
    
    return [(adj, adj_category) for adj in adjectives]


tokens = []
token_rows = 5
for i in range(0, len(adjective_expansion), token_rows+1):
    tokens.append(clean_adjective_df(adjective_expansion.loc[i:i+token_rows]))
high_tokens, low_tokens, fast_tokens, slow_tokens = tokens

adjective_class_map = dict(high_tokens + low_tokens + fast_tokens + slow_tokens)

# %% [markdown]
# ### Reading composition classes

# %%
semantic_classes_file = pd.ExcelFile('SEMANTIC_CLASSES.xlsx', engine = 'openpyxl')

dominator_neg = pd.read_excel(semantic_classes_file, 'DOMINATOR_NEG', header=None)[0].values.tolist()
dominator_pos = pd.read_excel(semantic_classes_file, 'DOMINATOR_POS', header=None)[0].values.tolist()
propagator_pos = pd.read_excel(semantic_classes_file, 'PROPAGATOR_POS', header=None)[0].values.tolist()
propagator_neg = pd.read_excel(semantic_classes_file, 'PROPAGATOR_NEG', header=None)[0].values.tolist()
reverser_pos = pd.read_excel(semantic_classes_file, 'REVERSER_POS', header=None)[0].values.tolist()
reverser_neg = pd.read_excel(semantic_classes_file, 'REVERSER_NEG', header=None)[0].values.tolist()

# %% [markdown]
# ### Calculate combined sentiment

# %%
class Adjective:
    FAST = 'FAST_TOKENS'
    SLOW = 'SLOW_TOKENS'
    HIGH = 'HIGH_TOKENS'
    LOW = 'LOW_TOKENS'
    
class Sign:
    POSITIVE = 'Positive'
    NEGATIVE = 'Negative'
    NEUTRAL = 'Neutral'

adjective_conditions = {
    Adjective.FAST: [(fast_slow_PN, Sign.POSITIVE), (fast_slow_NP, Sign.NEGATIVE)],
    Adjective.SLOW: [(fast_slow_PN, Sign.NEGATIVE), (fast_slow_NP, Sign.POSITIVE)],
    Adjective.HIGH: [(high_low_PN, Sign.POSITIVE), (high_low_NP, Sign.NEGATIVE)],
    Adjective.LOW: [(high_low_PN, Sign.NEGATIVE), (high_low_NP, Sign.POSITIVE)],
}

sentiment_to_score = {
    Sign.POSITIVE: +1,
    Sign.NEGATIVE: -1,
}

def is_given_sentiment(sentiment, word, sentiment_map):
    if word in sentiment_map:
        if sentiment==Sign.NEGATIVE and sentiment_map[word] < 0:
            return True
        elif sentiment==Sign.POSITIVE and sentiment_map[word] > 0:
            return True

def calculate_composition_or_adj_sentiment(bigram):
    # Adjective
    adjective_token = adjective_class_map.get(bigram[0])
    if adjective_token is not None:
        for expansions_list, sentiment_sign in adjective_conditions[adjective_token]:
            if bigram[1] in expansions_list:
                return sentiment_to_score[sentiment_sign]

    # Composition: Reverser
    elif bigram[0] in reverser_pos and is_given_sentiment(Sign.NEGATIVE, bigram[1], unigram_sentiment_dict):
        return sentiment_to_score[Sign.POSITIVE]
    elif bigram[0] in reverser_neg and is_given_sentiment(Sign.POSITIVE, bigram[1], unigram_sentiment_dict):
        return sentiment_to_score[Sign.NEGATIVE]

    # Composition: Propagator
    elif bigram[0] in propagator_pos and is_given_sentiment(Sign.NEGATIVE, bigram[0], unigram_sentiment_dict) and is_given_sentiment(Sign.POSITIVE, bigram[1], unigram_sentiment_dict):
        return sentiment_to_score[Sign.POSITIVE]
    elif bigram[0] in propagator_neg and is_given_sentiment(Sign.POSITIVE, bigram[0], unigram_sentiment_dict) and is_given_sentiment(Sign.NEGATIVE, bigram[1], unigram_sentiment_dict):
        return sentiment_to_score[Sign.NEGATIVE]

    # Composition: Dominator
    elif bigram[0] in dominator_neg:
        return sentiment_to_score[Sign.NEGATIVE]
    elif bigram[0] in dominator_pos:
        return sentiment_to_score[Sign.POSITIVE]
    
    return None

# %%
def calculate_unigram_sentiment(tokenized_sentence, sentiment_map=unigram_sentiment_dict):
    sentiment_score = 0
    for token in tokenized_sentence:
        token_sentiment = sentiment_map.get(token)
        if token_sentiment is None:
            continue
        else:
            sentiment_score += token_sentiment

    return sentiment_score

def calculate_bigram_sentiment(bigram):
    bigram_sentiment = bigram_sentiment_dict.get(bigram)
    if bigram_sentiment:
        # -0.02 and 0.02 allows for margin of error for neutrals
        if bigram_sentiment < -0.02:
            return -1
        elif bigram_sentiment > 0.02:
            return 1
        else:
            return 0
    return None


## TODO : punish the sentiment with distance from the subject entity before adding to current_sentiment
def calculate_sentiment_combined(sentence, tweet_id):
    
    table = str.maketrans(dict.fromkeys(string.punctuation))
    cleaned_sentence = sentence.translate(table)  # remove punctuation
    sentence_bigrams = list(
        nltk.bigrams(
            word_tokenize(
                cleaned_sentence.lower()
            )
        )
    )
    total_sentiment_score = 0.0
    try:
        for subject in subjects_per_tweet[tweet_id]:
            sentiment_score = 0
            p = 0.0
            n = 0.0
            for bigram in sentence_bigrams:
                current_sentiment = calculate_bigram_sentiment(bigram)
                if current_sentiment is None:
                    current_sentiment = calculate_composition_or_adj_sentiment(bigram)
                    if current_sentiment is None:
                        unigram_sentiment = calculate_unigram_sentiment(bigram)
                        if unigram_sentiment < - 0.1:
                            current_sentiment = -1
                        elif unigram_sentiment > 0.1:
                            current_sentiment = 1
                        else:
                            current_sentiment = 0
                # get the index of the bigram in the sentence
                ind = sentence.index(bigram)
                # calculate the distance between subject and bigram
                dis = min(
                    abs(ind - subject['begin']), 
                    abs(ind - subject['end']), 
                    abs(ind + len(bigram) - subject['begin'])
                )
                # punish the sentiment of a bigram for an opinion subject 
                if (current_sentiment/sqrt(dis)) < (-0.01):
                    n += (current_sentiment/sqrt(dis))
                elif (current_sentiment/sqrt(dis)) > 0.01:
                    p += (current_sentiment/sqrt(dis))
            # sentiment for a given subject 
            sentiment_score +=  (p+n)/(p-n+1)
            # update the polarity of subject
            subject['polarity'] = sentiment_score
            # update the score of the whole sentence
            total_sentiment_score += sentiment_score
        # take the average based on score with respect to different opnion subjects
        total_sentiment_score/= len(subjects_per_tweet)
    except:
        total_sentiment_score = 0.0
        for bigram in sentence_bigrams:
            current_sentiment = calculate_bigram_sentiment(bigram)
            if current_sentiment is None:
                current_sentiment = calculate_composition_or_adj_sentiment(bigram)
                if current_sentiment is None:
                    unigram_sentiment = calculate_unigram_sentiment(bigram)
                    if unigram_sentiment < - 0.1:
                        current_sentiment = -1
                    elif unigram_sentiment > 0.1:
                        current_sentiment = 1
                    else:
                        current_sentiment = 0
            total_sentiment_score += current_sentiment
    
    return total_sentiment_score

# %%
score_of_tweet = []
for i,r in tqdm(annotation_df.iterrows()):
    score = calculate_sentiment_combined(r['Tweet'], r['Tweet ID'])
    score_of_tweet.append(score)
# Out:
# 49404it [00:40, 1209.65it/s]

# %%
annotation_df['Scores'] = score_of_tweet

# %%
annotation_df.head()
# Out:
#                User ID                  Tweet ID  \
# 0   775702352523296770  5f1879402d4d197ddb3f7d88
# 1  1082351503354908672  5f1879412d4d197ddb3f7dc2
# 2  1234061913073618945  5f1879412d4d197ddb3f7e09
# 3  1209664517220659200  5f1879412d4d197ddb3f7e10
# 4  1026777124844306432  5f1879422d4d197ddb3f7e1f
#
#                                                Tweet  \
# 0  We want justice for  is my support in this fig...
# 1               Nhi raha ek kamyab insan #Candle4SSR
# 2          #Candle4SSR\n1 million for our real hero.
# 3  "Let's get mix more people with us for this fi...
# 4  Thanks  for being with us to seek justice! \nN...
#
#                        Hashtags  \
# 0  #Candle4SSR,#candle4sushant,
# 1                  #Candle4SSR,
# 2                  #Candle4SSR,
# 3      #Candle4SSR,#Candle4SSR,
# 4                  #Candle4SSR,
#
#                                         tagged users Language username  Scores
# 0  ['ishkarnBHANDARI', 'lostsoul_apu', 'justice_s...       en      NaN     6.0
# 1                                                 []       so      NaN     0.0
# 2                                                 []       en      NaN     1.0
# 3                                                 []       en      NaN     4.0
# 4             ['AkshayeOfficial', 'ishkarnBHANDARI']       en      NaN     5.0

# %% [markdown]
# # Calculating opnion distances

# %%
n = annotation_df.shape[0]
opinion_distance_matrix = []
for i in tqdm(range(n)):
    opinion_distance_matrix.append([])
    for j in range(n):
        opinion_distance_matrix[i].append(0)
# Out:
# 100%|██████████| 49404/49404 [04:34<00:00, 179.99it/s]

# %%
print(opinion_distance_matrix)
print(len(opinion_distance_matrix[0]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-125-e52a5da085a8> in <module>
# ----> 1 print(opinion_distance_matrix)
#       2 print(len(opinion_distance_matrix[0]))
#
# KeyboardInterrupt:

# %%
for i,r in tqdm(annotation_df.iterrows()):
    for j,k in annotation_df.iterrows():
        if subjects_per_tweet.get(r['Tweet ID']) and subjects_per_tweet.get(k['Tweet ID']):
            subjects_list1 = subjects_per_tweet[r['Tweet ID']]
            subjects_list2 = subjects_per_tweet[k['Tweet ID']]
            entity_titles1 = set(map(lambda x: x['entity_title'], subjects_list1))
            entity_titles2 = set(map(lambda x: x['entity_title'], subjects_list2))
            common_subjects = entity_titles1 - entity_titles2
            if len(common_subjects)>0:
                od = 0.0
                try:
                    polarities1 =  [x['polarity'] for x in subjects_list1 if x['entity_title'] in common_subjects]
                    polarities2 =  [x['polarity'] for x in subjects_list2 if x['entity_title'] in common_subjects]
                    m = len(polarities1) * len(polarities2)
                    for p1 in polarities1:
                        for p2 in polarities2:
                            od+= abs(p1-p2)
                    opinion_distance_matrix[i][j] = od/(2*m)
                except:
                    opinion_distance_matrix[i][j] = -3
            else:
                opinion_distance_matrix[i][j] = -3
        else:
            opinion_distance_matrix[i][j] = -3
# Out:
# 8it [00:33,  4.34s/it]

# %%
opinion_distance_matrix[0][1] = 0
opinion_distance_matrix[4][:10]
# Out:
# [-3, -3, -3, -3, -3, 0, 0, 0, 0, 0]
